# %% [markdown]
# <p style="align: center;"><img align=center src="https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg" width=500 height=450/></p>
#
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>
#
# <h3 style="text-align: center;"><b>Домашнее задание. Продвинутый поток. Весна 2021</b></h3>
#
# Это домашнее задание будет посвящено полноценному решению задачи машинного обучения.

# %% [markdown]
# Есть две части этого домашнего задания:
# * Сделать полноценный отчет о вашей работе: как вы обработали данные, какие модели попробовали и какие результаты получились (максимум 10 баллов). За каждую выполненную часть будет начислено определенное количество баллов.
# * Лучшее решение отправить в соревнование на [kaggle](https://www.kaggle.com/c/advanced-dls-spring-2021/) (максимум 5 баллов). За прохождение определенного порогов будут начисляться баллы.
#
#
# **Обе части будут проверяться в формате peer-review. Т.е. вашу посылку на степик будут проверять несколько других студентов и аггрегация их оценок будет выставлена. В то же время вам тоже нужно будет проверить несколько других учеников.**
#
# **Пожалуйста, делайте свою работу чистой и понятной, чтобы облегчить проверку. Если у вас будут проблемы с решением или хочется совета, то пишите в наш чат в телеграме или в лс @runfme. Если вы захотите проаппелировать оценку, то пипшите в лс @runfme.**
#
# **Во всех пунктах указания это минимальный набор вещей, которые стоит сделать. Если вы можете сделать какой-то шаг лучше или добавить что-то свое - дерзайте!**

# %% [markdown]
# # Как проверять?
#
# Ставьте полный балл, если выполнены все рекомендации или сделано что-то более интересное и сложное. За каждый отсустствующий пункт из рекомендация снижайте 1 балл.

# %% [markdown]
# # Метрика
#
# Перед решением любой задачи важно понимать, как будет оцениваться ваше решение. В данном случае мы используем стандартную для задачи классификации метрику ROC-AUC. Ее можно вычислить используя только предсказанные вероятности и истинные классы без конкретного порога классификации + она раотает даже если классы в данных сильно несбалансированны (примеров одного класса в десятки раз больше примеров длугого). Именно поэтому она очень удобна для соревнований.
#
# Посчитать ее легко:

# %%
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Первая часть. Исследование

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./train.csv')

# %%
# Для вашего удобства списки с именами разных колонок

# Числовые признаки
num_cols = [
    'ClientPeriod',
    'MonthlySpending',
    'TotalSpent'
]

# Категориальные признаки
cat_cols = [
    'Sex',
    'IsSeniorCitizen',
    'HasPartner',
    'HasChild',
    'HasPhoneService',
    'HasMultiplePhoneNumbers',
    'HasInternetService',
    'HasOnlineSecurityService',
    'HasOnlineBackup',
    'HasDeviceProtection',
    'HasTechSupportAccess',
    'HasOnlineTV',
    'HasMovieSubscription',
    'HasContractPhone',
    'IsBillingPaperless',
    'PaymentMethod'
]

feature_cols = num_cols + cat_cols
target_col = 'Churn'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5282 entries, 0 to 5281
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ClientPeriod              5282 non-null   int64
#  1   MonthlySpending           5282 non-null   float64
#  2   TotalSpent                5282 non-null   object
#  3   Sex                       5282 non-null   object
#  4   IsSeniorCitizen           5282 non-null   int64
#  5   HasPartner                5282 non-null   object
#  6   HasChild                  5282 non-null   object
#  7   HasPhoneService           5282 non-null   object
#  8   HasMultiplePhoneNumbers   5282 non-null   object
#  9   HasInternetService        5282 non-null   object
#  10  HasOnlineSecurityService  5282 non-null   object
#  11  HasOnlineBackup           5282 non-null   object
#  12  HasDeviceProtection       5282 non-null   object
#  13  HasTechSupportAccess      5282 non-null   object
#  14  HasOnlineTV               5282 non-null   object
#  15  HasMovieSubscription      5282 non-null   object
#  16  HasContractPhone          5282 non-null   object
#  17  IsBillingPaperless        5282 non-null   object
#  18  PaymentMethod             5282 non-null   object
#  19  Churn                     5282 non-null   int64
# dtypes: float64(1), int64(3), object(16)
# memory usage: 825.4+ KB

# %% [markdown]
# - Мы видим, что признак 'TotalSpent' иммет тип object , хотя является float. Нужно поменять. Однако это происходит потому, что тем есть пропущенные значения в виде пробела, т.е. " ".

# %%
data.loc[data['TotalSpent'] == ' ', 'TotalSpent'] = np.nan
data['TotalSpent'] = data['TotalSpent'].astype(float) # Поменяем тип
data.loc[data['TotalSpent'].isnull(), 'TotalSpent'] = data['TotalSpent'].median()
data['IsSeniorCitizen'] = data['IsSeniorCitizen'].astype(object) # Сделаем категориальную переменную, категориальной.

# %%
data.describe()
# Out:
#        ClientPeriod  MonthlySpending   TotalSpent        Churn
# count   5282.000000      5282.000000  5282.000000  5282.000000
# mean      32.397009        64.924754  2289.889086     0.262022
# std       24.550326        30.176464  2267.371263     0.439776
# min        0.000000        18.250000    18.800000     0.000000
# 25%        9.000000        35.462500   401.587500     0.000000
# 50%       29.000000        70.400000  1410.250000     0.000000
# 75%       55.000000        90.050000  3795.212500     1.000000
# max       72.000000       118.750000  8684.800000     1.000000

# %% [markdown]
# - Данные без Выбросов

# %%
data.head(5)
# Out:
#    ClientPeriod  MonthlySpending  TotalSpent     Sex IsSeniorCitizen  \
# 0            55            19.50     1026.35    Male               0
# 1            72            25.85     1872.20    Male               0
# 2             1            75.90       75.90    Male               0
# 3            32            79.30     2570.00  Female               1
# 4            60           115.25     6758.45  Female               0
#
#   HasPartner HasChild HasPhoneService HasMultiplePhoneNumbers  \
# 0        Yes      Yes             Yes                      No
# 1        Yes       No             Yes                     Yes
# 2         No       No             Yes                      No
# 3        Yes       No             Yes                     Yes
# 4        Yes      Yes             Yes                     Yes
#
#   HasInternetService HasOnlineSecurityService      HasOnlineBackup  \
# 0                 No      No internet service  No internet service
# 1                 No      No internet service  No internet service
# 2        Fiber optic                       No                   No
# 3        Fiber optic                       No                   No
# 4        Fiber optic                      Yes                  Yes
#
#    HasDeviceProtection HasTechSupportAccess          HasOnlineTV  \
# 0  No internet service  No internet service  No internet service
# 1  No internet service  No internet service  No internet service
# 2                   No                  Yes                   No
# 3                  Yes                   No                   No
# 4                  Yes                  Yes                  Yes
#
#   HasMovieSubscription HasContractPhone IsBillingPaperless  \
# 0  No internet service         One year                 No
# 1  No internet service         Two year                 No
# 2                   No   Month-to-month                Yes
# 3                   No   Month-to-month                 No
# 4                  Yes         Two year                 No
#
#              PaymentMethod  Churn
# 0             Mailed check      0
# 1  Credit card (automatic)      0
# 2         Electronic check      1
# 3             Mailed check      0
# 4  Credit card (automatic)      0

# %%
data['Churn'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Churn'].value_counts(normalize=True)
# Out:
# 0    0.737978
# 1    0.262022
# Name: Churn, dtype: float64

# %% [markdown]
# - Целевая переменная имеет дисбаланс, но не очень сильный.

# %% [markdown]
# #### По описательной статистике, мы видели, что на первый взгляд непрерывные признаки не имеют выбросов, для наглядности можем построить боксплоты и убедиться.

# %%
plt.figure(figsize=(15,3))
sns.boxplot(data['ClientPeriod']);

# %% [markdown]
# - Как мы видим выбросов нет. Посмотрим  на распределение целевой переменной в разрезе 'ClientPeriod'.

# %%
plt.figure(figsize=(15,3))
sns.boxplot(x='ClientPeriod', y='Churn', data=data[['ClientPeriod', 'Churn']], orient='h');

# %% [markdown]
# - Как мы видим распределение явно отличается, среднее 1 класса по этому признаку смещено ближе к 0.

# %%
churn_spread = data[['ClientPeriod', 'Churn']]
churn_1 = churn_spread.loc[churn_spread['Churn'] == 1, 'ClientPeriod']
churn_0 = churn_spread.loc[churn_spread['Churn'] == 0, 'ClientPeriod']
sns.kdeplot(churn_0, shade=True,  color='g')
sns.kdeplot(churn_1, shade=True,  color='r')
;
# Out:
# ''

# %% [markdown]
# - Исходя из наблюдений, можно сделать вывод, что люди на много чаще уходят при ClientPeriod (т.к. нет описания призноков, будем считать, что это время, которое человек провел пользуясь услугами.) близким к 0. Можно интерпритировать это, как то, что человек принимает решение,  о том, нравится ему компания или нет в первые дни. Как рекомендация, в период 0 - 20 предоставлять доп скидки.

# %%
plt.figure(figsize=(15,3))
sns.boxplot(data['MonthlySpending']);

# %% [markdown]
# - Как мы видим выбросов нет. Посмотрим  на распределение целевой переменной в разрезе 'ClientPeriod'.

# %%
plt.figure(figsize=(15,3))
sns.boxplot(x='MonthlySpending', y='Churn', data=data[['MonthlySpending', 'Churn']], orient='h');

# %% [markdown]
# - В целом распределение похоже, хотя средние также смещены. Посмотрим на плотность.

# %%
churn_spread = data[['MonthlySpending', 'Churn']]
churn_1 = churn_spread.loc[churn_spread['Churn'] == 1, 'MonthlySpending']
churn_0 = churn_spread.loc[churn_spread['Churn'] == 0, 'MonthlySpending']
sns.kdeplot(churn_0, shade=True,  color='g')
sns.kdeplot(churn_1, shade=True,  color='r')
# Out:
# <AxesSubplot:xlabel='MonthlySpending', ylabel='Density'>

# %% [markdown]
# - Видна прямая зависимость количества ушедших от ежемесячного расхода.

# %%
plt.figure(figsize=(15,3))
sns.boxplot(data['TotalSpent']);

# %% [markdown]
# - Выбросов нет.

# %%
plt.figure(figsize=(15,3))
sns.boxplot(x='TotalSpent', y='Churn', data=data[['TotalSpent', 'Churn']], orient='h');

# %%
churn_spread = data[['TotalSpent', 'Churn']]
churn_1 = churn_spread.loc[churn_spread['Churn'] == 1, 'TotalSpent']
churn_0 = churn_spread.loc[churn_spread['Churn'] == 0, 'TotalSpent']
sns.kdeplot(churn_0, shade=True,  color='g')
sns.kdeplot(churn_1, shade=True,  color='r')
# Out:
# <AxesSubplot:xlabel='TotalSpent', ylabel='Density'>

# %% [markdown]
# - Хоть средняя смещена, но не вижу выдающейся разницы, как на предыдущих признаках.

# %%
cols_for_pair = ['ClientPeriod','MonthlySpending', 'TotalSpent', 'Churn']

# %%
sns.pairplot(data=data[cols_for_pair], hue='Churn')

# %% [markdown]
# - Стоит обратить внимание, на большое скопление ушедших на пересечении больших месячных расходов и малого "клиентского периода".

# %%
sns.heatmap(data[num_cols].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Посмотри категориальные признаки

# %%
for cat in cat_cols:
    print(data[cat].value_counts())
# Out:
# Male      2655
# Female    2627
# Name: Sex, dtype: int64
# 0    4440
# 1     842
# Name: IsSeniorCitizen, dtype: int64
# No     2705
# Yes    2577
# Name: HasPartner, dtype: int64
# No     3676
# Yes    1606
# Name: HasChild, dtype: int64
# Yes    4761
# No      521
# Name: HasPhoneService, dtype: int64
# No                  2511
# Yes                 2250
# No phone service     521
# Name: HasMultiplePhoneNumbers, dtype: int64
# Fiber optic    2341
# DSL            1800
# No             1141
# Name: HasInternetService, dtype: int64
# No                     2612
# Yes                    1529
# No internet service    1141
# Name: HasOnlineSecurityService, dtype: int64
# No                     2332
# Yes                    1809
# No internet service    1141
# Name: HasOnlineBackup, dtype: int64
# No                     2317
# Yes                    1824
# No internet service    1141
# Name: HasDeviceProtection, dtype: int64
# No                     2604
# Yes                    1537
# No internet service    1141
# Name: HasTechSupportAccess, dtype: int64
# No                     2099
# Yes                    2042
# No internet service    1141
# Name: HasOnlineTV, dtype: int64
# No                     2081
# Yes                    2060
# No internet service    1141
# Name: HasMovieSubscription, dtype: int64
# Month-to-month    2920
# Two year          1280
# One year          1082
# Name: HasContractPhone, dtype: int64
# Yes    3148
# No     2134
# Name: IsBillingPaperless, dtype: int64
# Electronic check             1786
# Mailed check                 1194
# Bank transfer (automatic)    1159
# Credit card (automatic)      1143
# Name: PaymentMethod, dtype: int64

# %% [markdown]
# - Напишем функцию, чтобы можно было посмотреть распределение целевой переменной в каждой категории

# %%
def countplot_iter(list_cat_cols, target, data):
    for i in list_cat_cols:
        yield sns.countplot(x=i, hue=target, data=data);

# %%
iter = countplot_iter(cat_cols, "Churn", data)

# %%
next(iter)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# Пролистав все признаки, самыми интересными стали 'HasInternetService', 'HasOnlineSecurityService', 'HasOnlineBackup', 'HasDeviceProtection', 'HasTechSupportAccess', 'HasOnlineTV', 'HasMovieSubscription', 'HasContractPhone', 'PaymentMethod'

# %% [markdown]
# - Посмотрим те, которые меня заинтересовали больше всего.

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='PaymentMethod', hue="Churn", data=data)
# Out:
# <AxesSubplot:xlabel='PaymentMethod', ylabel='count'>

# %% [markdown]
# Посмотрите, как сильно выделяется распределение в подкатегории Electronic check. Можно сделать вывод, что у людей какие-то проблемы с оплатой через этот метод (возможно какйто налог или еще что). Вероятно даже имеет смысл сделать из этого признака бинарный  по подкатегории "Elecronic check" да\нет.

# %% [markdown]
# - Также Есть группа категориальных переменных начинающихся с Has% это означает подключенная услуга. Эти группы разделены логически на 2 подгруппы, Интернет сервисы и телефония.

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='HasInternetService', hue="Churn", data=data)
# Out:
# <AxesSubplot:xlabel='HasInternetService', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='HasOnlineBackup', hue="Churn", data=data)
# Out:
# <AxesSubplot:xlabel='HasOnlineBackup', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='HasDeviceProtection', hue="Churn", data=data)
# Out:
# <AxesSubplot:xlabel='HasDeviceProtection', ylabel='count'>

# %%
data.loc[data['HasInternetService'] == "No"].head(5)
# Out:
#     ClientPeriod  MonthlySpending  TotalSpent     Sex IsSeniorCitizen  \
# 0             55            19.50     1026.35    Male               0
# 1             72            25.85     1872.20    Male               0
# 5             25            19.80      475.20  Female               0
# 18            59            19.85     1188.25    Male               0
# 22            20            19.50      413.00  Female               0
#
#    HasPartner HasChild HasPhoneService HasMultiplePhoneNumbers  \
# 0         Yes      Yes             Yes                      No
# 1         Yes       No             Yes                     Yes
# 5          No       No             Yes                      No
# 18        Yes      Yes             Yes                      No
# 22         No       No             Yes                      No
#
#    HasInternetService HasOnlineSecurityService      HasOnlineBackup  \
# 0                  No      No internet service  No internet service
# 1                  No      No internet service  No internet service
# 5                  No      No internet service  No internet service
# 18                 No      No internet service  No internet service
# 22                 No      No internet service  No internet service
#
#     HasDeviceProtection HasTechSupportAccess          HasOnlineTV  \
# 0   No internet service  No internet service  No internet service
# 1   No internet service  No internet service  No internet service
# 5   No internet service  No internet service  No internet service
# 18  No internet service  No internet service  No internet service
# 22  No internet service  No internet service  No internet service
#
#    HasMovieSubscription HasContractPhone IsBillingPaperless  \
# 0   No internet service         One year                 No
# 1   No internet service         Two year                 No
# 5   No internet service         Two year                 No
# 18  No internet service         Two year                 No
# 22  No internet service   Month-to-month                Yes
#
#                 PaymentMethod  Churn
# 0                Mailed check      0
# 1     Credit card (automatic)      0
# 5     Credit card (automatic)      0
# 18               Mailed check      0
# 22  Bank transfer (automatic)      0

# %% [markdown]
# - Как мы видим, люди которые пользуются только телефонией, почти не отказываются от услуг.

# %% [markdown]
# Также еще один интересный признак 'HasTechSupportAccess', как видно из название это доступ к техподдержке.

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='HasTechSupportAccess', hue="Churn", data=data)
# Out:
# <AxesSubplot:xlabel='HasTechSupportAccess', ylabel='count'>

# %% [markdown]
# Посмотрите, какая большая разница между теми, кто не имел доступ и теми кто имел. Для маркетологов стоит задуматься, может имеет смысл сделать поддержку более "доступной".

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='HasContractPhone', hue="Churn", data=data)
# Out:
# <AxesSubplot:xlabel='HasContractPhone', ylabel='count'>

# %% [markdown]
# Можно интерпритировать, это как человек который платит на год или два вперед, уверен, что он не уйдет.=)

# %% [markdown]
# ## Строим модели

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder, OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.metrics import roc_auc_score, roc_curve

# %% [markdown]
# #### Сперва подготовим данные.

# %% [markdown]
# - Создаем дамми переменные

# %%
X = pd.get_dummies(data[feature_cols], drop_first=True)
y = data[target_col]

# %% [markdown]
# - Разделяем на трейн \ валид выборки

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=47)

# %% [markdown]
# - Стандартизируем

# %%
stand = StandardScaler()

# %%
X_train[num_cols] = stand.fit_transform(X_train[num_cols])
X_valid[num_cols] = stand.transform(X_valid[num_cols])

# %% [markdown]
# #### Теперь можно опробовать линейные модельки со стандартными параметрами.

# %% [markdown]
# #### № 1 LogisticRegressionCV стандарт

# %% [markdown]
# - Попробуем стандартную лог регрессию. По умолчанию тут используется L2 регуляризация.

# %%
lrcv = LogisticRegressionCV(cv = 5, scoring='roc_auc')
lrcv.fit(X_train, y_train)
# Out:
# LogisticRegressionCV(cv=5, scoring='roc_auc')

# %%
lrcv.get_params()
# Out:
# {'Cs': 10,
#  'class_weight': None,
#  'cv': 5,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1.0,
#  'l1_ratios': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'refit': True,
#  'scoring': 'roc_auc',
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0}

# %%
y_train_predicted = lrcv.predict_proba(X_train)[:, 1]
y_valid_predicted = lrcv.predict_proba(X_valid)[:, 1]

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
valid_auc = roc_auc_score(y_valid, y_valid_predicted)

plt.figure(figsize=(20,10))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_valid, y_valid_predicted)[:2], label='valid AUC={:.4f}'.format(valid_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %% [markdown]
# - Посмотрим на веса.

# %%
f_i = lrcv.coef_[0]
plt.figure(figsize=(10,10))
plt.barh(X_train.columns, f_i)
plt.show()

# %% [markdown]
# #### № 2 LogisticRegressionCV L1

# %% [markdown]
# - Попробуем тоже, но с L1 регуляризацией

# %%
lrcv_l1 = LogisticRegressionCV(cv = 5, scoring='roc_auc', penalty = "l1", solver = "liblinear")
lrcv_l1.fit(X_train, y_train)
# Out:
# LogisticRegressionCV(cv=5, penalty='l1', scoring='roc_auc', solver='liblinear')

# %%
y_train_predicted = lrcv_l1.predict_proba(X_train)[:, 1]
y_valid_predicted = lrcv_l1.predict_proba(X_valid)[:, 1]

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
valid_auc = roc_auc_score(y_valid, y_valid_predicted)

plt.figure(figsize=(20,10))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_valid, y_valid_predicted)[:2], label='valid AUC={:.4f}'.format(valid_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %%
f_i = lrcv_l1.coef_[0]
plt.figure(figsize=(10,10))
plt.barh(X_train.columns, f_i)
plt.show()

# %% [markdown]
# - Можно попробовать взять только самые сильные признаки

# %%
strong = ['ClientPeriod', 'TotalSpent', 'HasPhoneService_Yes', 'IsSeniorCitizen_1', 
         'IsBillingPaperless_Yes', 'HasMultiplePhoneNumbers_Yes', 'HasInternetService_Fiber optic',  'HasOnlineSecurityService_Yes', 'HasOnlineBackup_No internet service',
         'HasContractPhone_One year',
       'HasContractPhone_Two year','IsBillingPaperless_Yes']

# %%
lrcv_l1.fit(X_train[strong], y_train)
# Out:
# LogisticRegressionCV(cv=5, penalty='l1', scoring='roc_auc', solver='liblinear')

# %%
y_train_predicted = lrcv_l1.predict_proba(X_train[strong])[:, 1]
y_valid_predicted = lrcv_l1.predict_proba(X_valid[strong])[:, 1]

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
valid_auc = roc_auc_score(y_valid, y_valid_predicted)

plt.figure(figsize=(20,10))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_valid, y_valid_predicted)[:2], label='valid AUC={:.4f}'.format(valid_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %%
f_i = lrcv_l1.coef_[0]
plt.figure(figsize=(10,10))
plt.barh(X_train[strong].columns, f_i)
plt.show()

# %% [markdown]
# - Не особо помогло =)

# %% [markdown]
# #### № 3 KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()

parameters = {
    'n_neighbors': np.arange(25, 35),
}
gs = GridSearchCV(
    estimator=model,
    param_grid=parameters,
    scoring='roc_auc',
    cv=5,
)

# %%
gs.fit(X_train, y_train);

# %%
gs.best_params_
# Out:
# {'n_neighbors': 34}

# %%
y_train_predicted = gs.predict_proba(X_train)[:, 1]
y_valid_predicted = gs.predict_proba(X_valid)[:, 1]

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
valid_auc = roc_auc_score(y_valid, y_valid_predicted)

plt.figure(figsize=(20,10))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_valid, y_valid_predicted)[:2], label='valid AUC={:.4f}'.format(valid_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %% [markdown]
# #### № 4 SVC

# %%
from sklearn.svm import SVC

# %%
model = SVC(probability=True)

parameters = {
    'C': [0.01, 0.1],
}
gs = GridSearchCV(
    estimator=model,
    param_grid=parameters,
    scoring='roc_auc',
    cv=5,
)

# %%
gs.fit(X_train, y_train);

# %%
gs.best_params_
# Out:
# {'C': 0.01}

# %%
y_train_predicted = gs.predict_proba(X_train)[:, 1]
y_valid_predicted = gs.predict_proba(X_valid)[:, 1]

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
valid_auc = roc_auc_score(y_valid, y_valid_predicted)

plt.figure(figsize=(20,10))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_valid, y_valid_predicted)[:2], label='valid AUC={:.4f}'.format(valid_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %% [markdown]
# - Точность оказалась по ниже, при том, что и скорость обучения такого алгоритма маловата. Попробуем использовать только сильные признаки.

# %%
model = SVC(probability=True)

parameters = {
    'C': [0.01, 0.1],
}
gs = GridSearchCV(
    estimator=model,
    param_grid=parameters,
    scoring='roc_auc',
    cv=5,
)

# %%
gs.fit(X_train[strong], y_train);
gs.best_params_
# Out:
# {'C': 0.01}

# %%
y_train_predicted = gs.predict_proba(X_train[strong])[:, 1]
y_valid_predicted = gs.predict_proba(X_valid[strong])[:, 1]

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
valid_auc = roc_auc_score(y_valid, y_valid_predicted)

plt.figure(figsize=(20,10))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_valid, y_valid_predicted)[:2], label='valid AUC={:.4f}'.format(valid_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %% [markdown]
# - Чтож, из линейных моделей самой бодрой получилась логистическая регрессия с L1 регуляризацией.
# - Параметры: LogisticRegressionCV(cv=5, penalty='l1', scoring='roc_auc', solver='liblinear')
# - Качество auc_score на валидационной выборке: 0.8545

# %% [markdown]
# ## Применение градиентного бустинга (2 балла)
#
# Если вы хотите получить баллы за точный ответ, то стоит попробовать градиентный бустинг. Часто градиентный бустинг с дефолтными параметрами даст вам 80% результата за 0% усилий.
#
# Мы будем использовать catboost, поэтому нам не надо кодировать категориальные признаки. catboost сделает это сам (в .fit() надо передать cat_features=cat_cols). А численные признаки нормировать для моделей, основанных на деревьях не нужно.
#
# 1) Разделите выборку на train/valid. Протестируйте catboost cо стандартными параметрами.
#
# 2) Протестируйте разные занчения параметроа количества деревьев и learning_rate'а и выберите лучшую по метрике ROC-AUC комбинацию.
#
# (Дополнительно) Есть некоторые сложности с тем, чтобы использовать CatBoostClassifier вместе с GridSearchCV, поэтому мы не просим использовать кроссвалидацию. Но можете попробовать)

# %%
from sklearn.ensemble import RandomForestClassifier
import xgboost
import catboost

# %% [markdown]
# #### №1 Простой лес

# %%
model = RandomForestClassifier()

parameters = {
    'n_estimators': [100,200,400],
    'max_depth': [4,5],
    'max_features': ['sqrt', 'log2'],
    
     
    
    
}
gs = GridSearchCV(
    estimator=model,
    param_grid=parameters,
    scoring='roc_auc',
    cv=5,
)

# %%
gs.fit(X_train, y_train);
gs.best_params_
# Out:
# {'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}

# %%
y_train_predicted = gs.predict_proba(X_train)[:, 1]
y_valid_predicted = gs.predict_proba(X_valid)[:, 1]

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
valid_auc = roc_auc_score(y_valid, y_valid_predicted)

plt.figure(figsize=(20,10))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_valid, y_valid_predicted)[:2], label='valid AUC={:.4f}'.format(valid_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %% [markdown]
# #### №2 Xgboost

# %%
model = xgboost.XGBClassifier(verbosity=0, gamma = 0.2, learning_rate = 0.09)

parameters = {
    'n_estimators': [70,150,100,200],
  'max_depth': [3,4,5,6,7,8], 

}
gs = GridSearchCV(
    estimator=model,
    param_grid=parameters,
    scoring='roc_auc',
    cv=5,
)

# %%
gs.fit(X_train, y_train);

# %%
y_train_predicted = gs.predict_proba(X_train)[:, 1]
y_valid_predicted = gs.predict_proba(X_valid)[:, 1]

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
valid_auc = roc_auc_score(y_valid, y_valid_predicted)

plt.figure(figsize=(20,10))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_valid, y_valid_predicted)[:2], label='valid AUC={:.4f}'.format(valid_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %% [markdown]
# #### №3 catboost

# %%
X_train_cb, X_valid_cb, y_train, y_valid = train_test_split(data.drop("Churn", axis = 1), data['Churn'], test_size=0.3, random_state=47)

# %%
boosting_model = catboost.CatBoostClassifier( 
                                             cat_features=cat_cols)

# %%
boosting_model.fit(X_train_cb, y_train);
# Out:
# Learning rate set to 0.017993
# 0:	learn: 0.6807371	total: 12ms	remaining: 12s
# 1:	learn: 0.6702785	total: 22.3ms	remaining: 11.1s
# 2:	learn: 0.6608273	total: 32.2ms	remaining: 10.7s
# 3:	learn: 0.6508171	total: 41.7ms	remaining: 10.4s
# 4:	learn: 0.6400328	total: 52ms	remaining: 10.3s
# 5:	learn: 0.6305375	total: 61.9ms	remaining: 10.2s
# 6:	learn: 0.6217981	total: 72.4ms	remaining: 10.3s
# 7:	learn: 0.6137928	total: 80.4ms	remaining: 9.97s
# 8:	learn: 0.6059339	total: 91.7ms	remaining: 10.1s
# 9:	learn: 0.5987913	total: 99.7ms	remaining: 9.87s
# 10:	learn: 0.5907022	total: 110ms	remaining: 9.88s
# 11:	learn: 0.5837680	total: 119ms	remaining: 9.82s
# 12:	learn: 0.5777033	total: 125ms	remaining: 9.45s
# 13:	learn: 0.5715485	total: 151ms	remaining: 10.7s
# 14:	learn: 0.5660138	total: 166ms	remaining: 10.9s
# 15:	learn: 0.5590873	total: 176ms	remaining: 10.8s
# 16:	learn: 0.5541856	total: 182ms	remaining: 10.5s
# 17:	learn: 0.5494981	total: 190ms	remaining: 10.4s
# 18:	learn: 0.5439354	total: 200ms	remaining: 10.3s
# 19:	learn: 0.5397896	total: 209ms	remaining: 10.2s
# 20:	learn: 0.5350019	total: 235ms	remaining: 10.9s
# 21:	learn: 0.5301586	total: 258ms	remaining: 11.5s
# 22:	learn: 0.5263089	total: 294ms	remaining: 12.5s
# 23:	learn: 0.5218378	total: 306ms	remaining: 12.4s
# 24:	learn: 0.5179509	total: 344ms	remaining: 13.4s
# 25:	learn: 0.5153109	total: 353ms	remaining: 13.2s
# 26:	learn: 0.5117581	total: 364ms	remaining: 13.1s
# 27:	learn: 0.5078826	total: 405ms	remaining: 14.1s
# 28:	learn: 0.5044614	total: 414ms	remaining: 13.9s
# 29:	learn: 0.5010979	total: 425ms	remaining: 13.8s
# 30:	learn: 0.4976476	total: 436ms	remaining: 13.6s
# 31:	learn: 0.4944084	total: 448ms	remaining: 13.6s
# 32:	learn: 0.4914740	total: 459ms	remaining: 13.5s
# 33:	learn: 0.4885991	total: 490ms	remaining: 13.9s
# 34:	learn: 0.4863190	total: 498ms	remaining: 13.7s
# 35:	learn: 0.4845600	total: 525ms	remaining: 14s
# 36:	learn: 0.4818616	total: 535ms	remaining: 13.9s
# 37:	learn: 0.4795679	total: 546ms	remaining: 13.8s
# 38:	learn: 0.4771678	total: 556ms	remaining: 13.7s
# 39:	learn: 0.4755666	total: 566ms	remaining: 13.6s
# 40:	learn: 0.4742439	total: 573ms	remaining: 13.4s
# 41:	learn: 0.4721227	total: 581ms	remaining: 13.3s
# 42:	learn: 0.4701015	total: 593ms	remaining: 13.2s
# 43:	learn: 0.4679432	total: 604ms	remaining: 13.1s
# 44:	learn: 0.4659814	total: 614ms	remaining: 13s
# 45:	learn: 0.4641147	total: 625ms	remaining: 13s
# 46:	learn: 0.4622074	total: 635ms	remaining: 12.9s
# 47:	learn: 0.4604396	total: 645ms	remaining: 12.8s
# 48:	learn: 0.4587425	total: 655ms	remaining: 12.7s
# 49:	learn: 0.4572244	total: 665ms	remaining: 12.6s
# 50:	learn: 0.4558013	total: 675ms	remaining: 12.6s
# 51:	learn: 0.4542108	total: 685ms	remaining: 12.5s
# 52:	learn: 0.4528952	total: 695ms	remaining: 12.4s
# 53:	learn: 0.4511867	total: 705ms	remaining: 12.4s
# 54:	learn: 0.4497332	total: 715ms	remaining: 12.3s
# 55:	learn: 0.4485934	total: 725ms	remaining: 12.2s
# 56:	learn: 0.4472585	total: 735ms	remaining: 12.2s
# 57:	learn: 0.4464760	total: 742ms	remaining: 12.1s
# 58:	learn: 0.4450737	total: 776ms	remaining: 12.4s
# 59:	learn: 0.4441231	total: 804ms	remaining: 12.6s
# 60:	learn: 0.4428082	total: 818ms	remaining: 12.6s
# 61:	learn: 0.4417517	total: 830ms	remaining: 12.6s
# 62:	learn: 0.4408593	total: 857ms	remaining: 12.8s
# 63:	learn: 0.4398703	total: 879ms	remaining: 12.9s
# 64:	learn: 0.4394558	total: 929ms	remaining: 13.4s
# 65:	learn: 0.4380757	total: 945ms	remaining: 13.4s
# 66:	learn: 0.4371792	total: 956ms	remaining: 13.3s
# 67:	learn: 0.4360647	total: 966ms	remaining: 13.2s
# 68:	learn: 0.4349975	total: 977ms	remaining: 13.2s
# 69:	learn: 0.4338605	total: 986ms	remaining: 13.1s
# 70:	learn: 0.4329485	total: 996ms	remaining: 13s
# 71:	learn: 0.4320289	total: 1.01s	remaining: 13s
# 72:	learn: 0.4309752	total: 1.02s	remaining: 13s
# 73:	learn: 0.4301299	total: 1.04s	remaining: 13s
# 74:	learn: 0.4293521	total: 1.07s	remaining: 13.2s
# 75:	learn: 0.4287255	total: 1.11s	remaining: 13.5s
# 76:	learn: 0.4282736	total: 1.12s	remaining: 13.4s
# 77:	learn: 0.4276388	total: 1.13s	remaining: 13.4s
# 78:	learn: 0.4269336	total: 1.14s	remaining: 13.3s
# 79:	learn: 0.4264571	total: 1.17s	remaining: 13.4s
# 80:	learn: 0.4258787	total: 1.19s	remaining: 13.5s
# 81:	learn: 0.4253004	total: 1.24s	remaining: 13.9s
# 82:	learn: 0.4244516	total: 1.25s	remaining: 13.8s
# 83:	learn: 0.4238662	total: 1.28s	remaining: 14s
# 84:	learn: 0.4232557	total: 1.3s	remaining: 14s
# 85:	learn: 0.4226745	total: 1.31s	remaining: 14s
# 86:	learn: 0.4221221	total: 1.32s	remaining: 13.9s
# 87:	learn: 0.4217539	total: 1.34s	remaining: 13.9s
# 88:	learn: 0.4212644	total: 1.35s	remaining: 13.8s
# 89:	learn: 0.4206820	total: 1.36s	remaining: 13.7s
# 90:	learn: 0.4202134	total: 1.37s	remaining: 13.7s
# 91:	learn: 0.4196554	total: 1.4s	remaining: 13.8s
# 92:	learn: 0.4192058	total: 1.44s	remaining: 14s
# 93:	learn: 0.4186072	total: 1.45s	remaining: 14s
# 94:	learn: 0.4181212	total: 1.49s	remaining: 14.2s
# 95:	learn: 0.4178693	total: 1.5s	remaining: 14.1s
# 96:	learn: 0.4175579	total: 1.51s	remaining: 14.1s
# 97:	learn: 0.4170772	total: 1.52s	remaining: 14s
# 98:	learn: 0.4166571	total: 1.53s	remaining: 13.9s
# 99:	learn: 0.4163697	total: 1.54s	remaining: 13.8s
# 100:	learn: 0.4158003	total: 1.55s	remaining: 13.8s
# 101:	learn: 0.4151194	total: 1.56s	remaining: 13.7s
# 102:	learn: 0.4144852	total: 1.58s	remaining: 13.8s
# 103:	learn: 0.4140750	total: 1.6s	remaining: 13.8s
# 104:	learn: 0.4136477	total: 1.61s	remaining: 13.7s
# 105:	learn: 0.4135578	total: 1.61s	remaining: 13.6s
# 106:	learn: 0.4134944	total: 1.62s	remaining: 13.5s
# 107:	learn: 0.4132135	total: 1.63s	remaining: 13.4s
# 108:	learn: 0.4131137	total: 1.63s	remaining: 13.3s
# 109:	learn: 0.4129737	total: 1.64s	remaining: 13.3s
# 110:	learn: 0.4125842	total: 1.66s	remaining: 13.3s
# 111:	learn: 0.4121997	total: 1.67s	remaining: 13.3s
# 112:	learn: 0.4118479	total: 1.69s	remaining: 13.3s
# 113:	learn: 0.4113216	total: 1.7s	remaining: 13.2s
# 114:	learn: 0.4110164	total: 1.73s	remaining: 13.3s
# 115:	learn: 0.4107625	total: 1.74s	remaining: 13.3s
# 116:	learn: 0.4102209	total: 1.76s	remaining: 13.3s
# 117:	learn: 0.4100280	total: 1.77s	remaining: 13.3s
# 118:	learn: 0.4098231	total: 1.79s	remaining: 13.2s
# 119:	learn: 0.4095600	total: 1.8s	remaining: 13.2s
# 120:	learn: 0.4092322	total: 1.81s	remaining: 13.2s
# 121:	learn: 0.4087445	total: 1.82s	remaining: 13.1s
# 122:	learn: 0.4085427	total: 1.83s	remaining: 13.1s
# 123:	learn: 0.4081050	total: 1.84s	remaining: 13s
# 124:	learn: 0.4078623	total: 1.86s	remaining: 13s
# 125:	learn: 0.4077110	total: 1.89s	remaining: 13.1s
# 126:	learn: 0.4074793	total: 1.9s	remaining: 13.1s
# 127:	learn: 0.4074262	total: 1.91s	remaining: 13s
# 128:	learn: 0.4070921	total: 1.92s	remaining: 12.9s
# 129:	learn: 0.4066065	total: 1.93s	remaining: 12.9s
# 130:	learn: 0.4065552	total: 1.93s	remaining: 12.8s
# 131:	learn: 0.4063566	total: 1.94s	remaining: 12.8s
# 132:	learn: 0.4058739	total: 1.95s	remaining: 12.7s
# 133:	learn: 0.4058304	total: 1.97s	remaining: 12.7s
# 134:	learn: 0.4055610	total: 1.98s	remaining: 12.7s
# 135:	learn: 0.4052438	total: 1.99s	remaining: 12.6s
# 136:	learn: 0.4048617	total: 2s	remaining: 12.6s
# 137:	learn: 0.4046395	total: 2.01s	remaining: 12.6s
# 138:	learn: 0.4043206	total: 2.03s	remaining: 12.6s
# 139:	learn: 0.4039225	total: 2.04s	remaining: 12.5s
# 140:	learn: 0.4036268	total: 2.06s	remaining: 12.6s
# 141:	learn: 0.4034204	total: 2.07s	remaining: 12.5s
# 142:	learn: 0.4030005	total: 2.08s	remaining: 12.5s
# 143:	learn: 0.4027265	total: 2.1s	remaining: 12.5s
# 144:	learn: 0.4023768	total: 2.12s	remaining: 12.5s
# 145:	learn: 0.4020865	total: 2.13s	remaining: 12.5s
# 146:	learn: 0.4017719	total: 2.14s	remaining: 12.4s
# 147:	learn: 0.4015775	total: 2.16s	remaining: 12.4s
# 148:	learn: 0.4011827	total: 2.17s	remaining: 12.4s
# 149:	learn: 0.4009664	total: 2.18s	remaining: 12.3s
# 150:	learn: 0.4009378	total: 2.18s	remaining: 12.3s
# 151:	learn: 0.4007889	total: 2.19s	remaining: 12.2s
# 152:	learn: 0.4004032	total: 2.21s	remaining: 12.2s
# 153:	learn: 0.4003585	total: 2.21s	remaining: 12.2s
# 154:	learn: 0.4002231	total: 2.23s	remaining: 12.1s
# 155:	learn: 0.3999934	total: 2.24s	remaining: 12.1s
# 156:	learn: 0.3996811	total: 2.25s	remaining: 12.1s
# 157:	learn: 0.3993874	total: 2.27s	remaining: 12.1s
# 158:	learn: 0.3991580	total: 2.28s	remaining: 12.1s
# 159:	learn: 0.3989634	total: 2.29s	remaining: 12s
# 160:	learn: 0.3987532	total: 2.3s	remaining: 12s
# 161:	learn: 0.3983494	total: 2.31s	remaining: 11.9s
# 162:	learn: 0.3983481	total: 2.31s	remaining: 11.9s
# 163:	learn: 0.3981689	total: 2.32s	remaining: 11.8s
# 164:	learn: 0.3978319	total: 2.33s	remaining: 11.8s
# 165:	learn: 0.3976875	total: 2.34s	remaining: 11.8s
# 166:	learn: 0.3974927	total: 2.35s	remaining: 11.7s
# 167:	learn: 0.3971784	total: 2.37s	remaining: 11.7s
# 168:	learn: 0.3969400	total: 2.39s	remaining: 11.7s
# 169:	learn: 0.3965832	total: 2.4s	remaining: 11.7s
# 170:	learn: 0.3963571	total: 2.42s	remaining: 11.7s
# 171:	learn: 0.3963293	total: 2.44s	remaining: 11.8s
# 172:	learn: 0.3962365	total: 2.46s	remaining: 11.8s
# 173:	learn: 0.3962178	total: 2.47s	remaining: 11.7s
# 174:	learn: 0.3961057	total: 2.48s	remaining: 11.7s
# 175:	learn: 0.3957218	total: 2.51s	remaining: 11.7s
# 176:	learn: 0.3955315	total: 2.52s	remaining: 11.7s
# 177:	learn: 0.3953092	total: 2.54s	remaining: 11.8s
# 178:	learn: 0.3952221	total: 2.58s	remaining: 11.9s
# 179:	learn: 0.3950806	total: 2.6s	remaining: 11.8s
# 180:	learn: 0.3949262	total: 2.61s	remaining: 11.8s
# 181:	learn: 0.3947794	total: 2.62s	remaining: 11.8s
# 182:	learn: 0.3947790	total: 2.62s	remaining: 11.7s
# 183:	learn: 0.3945557	total: 2.63s	remaining: 11.7s
# 184:	learn: 0.3943489	total: 2.65s	remaining: 11.7s
# 185:	learn: 0.3942046	total: 2.66s	remaining: 11.6s
# 186:	learn: 0.3940283	total: 2.67s	remaining: 11.6s
# 187:	learn: 0.3938033	total: 2.68s	remaining: 11.6s
# 188:	learn: 0.3937082	total: 2.69s	remaining: 11.6s
# 189:	learn: 0.3936313	total: 2.7s	remaining: 11.5s
# 190:	learn: 0.3936056	total: 2.71s	remaining: 11.5s
# 191:	learn: 0.3935727	total: 2.71s	remaining: 11.4s
# 192:	learn: 0.3933676	total: 2.74s	remaining: 11.4s
# 193:	learn: 0.3932420	total: 2.76s	remaining: 11.5s
# 194:	learn: 0.3930311	total: 2.77s	remaining: 11.4s
# 195:	learn: 0.3930306	total: 2.78s	remaining: 11.4s
# 196:	learn: 0.3930076	total: 2.78s	remaining: 11.3s
# 197:	learn: 0.3929360	total: 2.79s	remaining: 11.3s
# 198:	learn: 0.3929213	total: 2.79s	remaining: 11.2s
# 199:	learn: 0.3927698	total: 2.8s	remaining: 11.2s
# 200:	learn: 0.3924793	total: 2.81s	remaining: 11.2s
# 201:	learn: 0.3924474	total: 2.82s	remaining: 11.1s
# 202:	learn: 0.3922086	total: 2.83s	remaining: 11.1s
# 203:	learn: 0.3920937	total: 2.85s	remaining: 11.1s
# 204:	learn: 0.3919330	total: 2.86s	remaining: 11.1s
# 205:	learn: 0.3917651	total: 2.87s	remaining: 11s
# 206:	learn: 0.3916182	total: 2.88s	remaining: 11s
# 207:	learn: 0.3915684	total: 2.89s	remaining: 11s
# 208:	learn: 0.3914104	total: 2.93s	remaining: 11.1s
# 209:	learn: 0.3913386	total: 2.94s	remaining: 11.1s
# 210:	learn: 0.3911094	total: 2.95s	remaining: 11s
# 211:	learn: 0.3910055	total: 2.96s	remaining: 11s
# 212:	learn: 0.3907772	total: 2.97s	remaining: 11s
# 213:	learn: 0.3906677	total: 2.98s	remaining: 10.9s
# 214:	learn: 0.3904290	total: 2.99s	remaining: 10.9s
# 215:	learn: 0.3904240	total: 3s	remaining: 10.9s
# 216:	learn: 0.3902039	total: 3.01s	remaining: 10.9s
# 217:	learn: 0.3900059	total: 3.03s	remaining: 10.9s
# 218:	learn: 0.3899877	total: 3.06s	remaining: 10.9s
# 219:	learn: 0.3897992	total: 3.07s	remaining: 10.9s
# 220:	learn: 0.3897093	total: 3.08s	remaining: 10.9s
# 221:	learn: 0.3894301	total: 3.09s	remaining: 10.8s
# 222:	learn: 0.3892814	total: 3.11s	remaining: 10.8s
# 223:	learn: 0.3891790	total: 3.13s	remaining: 10.8s
# 224:	learn: 0.3891137	total: 3.14s	remaining: 10.8s
# 225:	learn: 0.3890857	total: 3.15s	remaining: 10.8s
# 226:	learn: 0.3889835	total: 3.16s	remaining: 10.8s
# 227:	learn: 0.3889419	total: 3.17s	remaining: 10.7s
# 228:	learn: 0.3888410	total: 3.19s	remaining: 10.7s
# 229:	learn: 0.3887660	total: 3.2s	remaining: 10.7s
# 230:	learn: 0.3883927	total: 3.21s	remaining: 10.7s
# 231:	learn: 0.3882588	total: 3.22s	remaining: 10.7s
# 232:	learn: 0.3881665	total: 3.24s	remaining: 10.7s
# 233:	learn: 0.3881382	total: 3.25s	remaining: 10.7s
# 234:	learn: 0.3879807	total: 3.27s	remaining: 10.6s
# 235:	learn: 0.3877246	total: 3.28s	remaining: 10.6s
# 236:	learn: 0.3876313	total: 3.29s	remaining: 10.6s
# 237:	learn: 0.3876062	total: 3.31s	remaining: 10.6s
# 238:	learn: 0.3873474	total: 3.33s	remaining: 10.6s
# 239:	learn: 0.3871569	total: 3.4s	remaining: 10.8s
# 240:	learn: 0.3870510	total: 3.42s	remaining: 10.8s
# 241:	learn: 0.3869666	total: 3.43s	remaining: 10.7s
# 242:	learn: 0.3867325	total: 3.44s	remaining: 10.7s
# 243:	learn: 0.3866837	total: 3.45s	remaining: 10.7s
# 244:	learn: 0.3865333	total: 3.47s	remaining: 10.7s
# 245:	learn: 0.3864701	total: 3.48s	remaining: 10.7s
# 246:	learn: 0.3863904	total: 3.49s	remaining: 10.6s
# 247:	learn: 0.3863278	total: 3.5s	remaining: 10.6s
# 248:	learn: 0.3862434	total: 3.51s	remaining: 10.6s
# 249:	learn: 0.3862139	total: 3.51s	remaining: 10.5s
# 250:	learn: 0.3861475	total: 3.52s	remaining: 10.5s
# 251:	learn: 0.3859862	total: 3.54s	remaining: 10.5s
# 252:	learn: 0.3859447	total: 3.55s	remaining: 10.5s
# 253:	learn: 0.3858750	total: 3.56s	remaining: 10.5s
# 254:	learn: 0.3858584	total: 3.58s	remaining: 10.4s
# 255:	learn: 0.3856202	total: 3.59s	remaining: 10.4s
# 256:	learn: 0.3855841	total: 3.6s	remaining: 10.4s
# 257:	learn: 0.3854562	total: 3.61s	remaining: 10.4s
# 258:	learn: 0.3854531	total: 3.62s	remaining: 10.4s
# 259:	learn: 0.3853661	total: 3.67s	remaining: 10.4s
# 260:	learn: 0.3851235	total: 3.68s	remaining: 10.4s
# 261:	learn: 0.3849779	total: 3.69s	remaining: 10.4s
# 262:	learn: 0.3848884	total: 3.71s	remaining: 10.4s
# 263:	learn: 0.3848694	total: 3.71s	remaining: 10.4s
# 264:	learn: 0.3848291	total: 3.72s	remaining: 10.3s
# 265:	learn: 0.3848291	total: 3.73s	remaining: 10.3s
# 266:	learn: 0.3847728	total: 3.73s	remaining: 10.3s
# 267:	learn: 0.3847716	total: 3.74s	remaining: 10.2s
# 268:	learn: 0.3846830	total: 3.79s	remaining: 10.3s
# 269:	learn: 0.3846427	total: 3.8s	remaining: 10.3s
# 270:	learn: 0.3846034	total: 3.84s	remaining: 10.3s
# 271:	learn: 0.3843932	total: 3.87s	remaining: 10.3s
# 272:	learn: 0.3843138	total: 3.88s	remaining: 10.3s
# 273:	learn: 0.3841794	total: 3.89s	remaining: 10.3s
# 274:	learn: 0.3841099	total: 3.9s	remaining: 10.3s
# 275:	learn: 0.3841099	total: 3.9s	remaining: 10.2s
# 276:	learn: 0.3841099	total: 3.9s	remaining: 10.2s
# 277:	learn: 0.3840957	total: 3.91s	remaining: 10.2s
# 278:	learn: 0.3840869	total: 3.91s	remaining: 10.1s
# 279:	learn: 0.3839792	total: 3.92s	remaining: 10.1s
# 280:	learn: 0.3838422	total: 3.93s	remaining: 10.1s
# 281:	learn: 0.3838252	total: 3.96s	remaining: 10.1s
# 282:	learn: 0.3838218	total: 3.97s	remaining: 10.1s
# 283:	learn: 0.3837991	total: 3.98s	remaining: 10s
# 284:	learn: 0.3836363	total: 4s	remaining: 10s
# 285:	learn: 0.3834354	total: 4.01s	remaining: 10s
# 286:	learn: 0.3833907	total: 4.02s	remaining: 9.98s
# 287:	learn: 0.3833805	total: 4.02s	remaining: 9.95s
# 288:	learn: 0.3833126	total: 4.05s	remaining: 9.97s
# 289:	learn: 0.3833022	total: 4.06s	remaining: 9.95s
# 290:	learn: 0.3833022	total: 4.07s	remaining: 9.91s
# 291:	learn: 0.3832906	total: 4.08s	remaining: 9.89s
# 292:	learn: 0.3832428	total: 4.08s	remaining: 9.86s
# 293:	learn: 0.3831357	total: 4.09s	remaining: 9.83s
# 294:	learn: 0.3831232	total: 4.11s	remaining: 9.83s
# 295:	learn: 0.3830182	total: 4.12s	remaining: 9.8s
# 296:	learn: 0.3829648	total: 4.13s	remaining: 9.78s
# 297:	learn: 0.3829316	total: 4.14s	remaining: 9.76s
# 298:	learn: 0.3829316	total: 4.15s	remaining: 9.72s
# 299:	learn: 0.3828337	total: 4.15s	remaining: 9.69s
# 300:	learn: 0.3827486	total: 4.16s	remaining: 9.67s
# 301:	learn: 0.3826750	total: 4.17s	remaining: 9.64s
# 302:	learn: 0.3825453	total: 4.18s	remaining: 9.62s
# 303:	learn: 0.3824778	total: 4.22s	remaining: 9.65s
# 304:	learn: 0.3823366	total: 4.23s	remaining: 9.65s
# 305:	learn: 0.3821324	total: 4.24s	remaining: 9.62s
# 306:	learn: 0.3819686	total: 4.25s	remaining: 9.6s
# 307:	learn: 0.3819291	total: 4.28s	remaining: 9.63s
# 308:	learn: 0.3819023	total: 4.31s	remaining: 9.63s
# 309:	learn: 0.3818151	total: 4.32s	remaining: 9.61s
# 310:	learn: 0.3817647	total: 4.34s	remaining: 9.62s
# 311:	learn: 0.3817647	total: 4.35s	remaining: 9.59s
# 312:	learn: 0.3817640	total: 4.35s	remaining: 9.55s
# 313:	learn: 0.3817445	total: 4.36s	remaining: 9.53s
# 314:	learn: 0.3817057	total: 4.4s	remaining: 9.57s
# 315:	learn: 0.3817057	total: 4.4s	remaining: 9.53s
# 316:	learn: 0.3815852	total: 4.42s	remaining: 9.52s
# 317:	learn: 0.3815435	total: 4.43s	remaining: 9.49s
# 318:	learn: 0.3814473	total: 4.44s	remaining: 9.48s
# 319:	learn: 0.3812875	total: 4.47s	remaining: 9.49s
# 320:	learn: 0.3812588	total: 4.48s	remaining: 9.48s
# 321:	learn: 0.3812127	total: 4.49s	remaining: 9.46s
# 322:	learn: 0.3811664	total: 4.5s	remaining: 9.43s
# 323:	learn: 0.3811664	total: 4.5s	remaining: 9.4s
# 324:	learn: 0.3811586	total: 4.51s	remaining: 9.37s
# 325:	learn: 0.3811184	total: 4.52s	remaining: 9.35s
# 326:	learn: 0.3810005	total: 4.54s	remaining: 9.35s
# 327:	learn: 0.3809483	total: 4.56s	remaining: 9.34s
# 328:	learn: 0.3809351	total: 4.56s	remaining: 9.31s
# 329:	learn: 0.3809350	total: 4.57s	remaining: 9.28s
# 330:	learn: 0.3808840	total: 4.58s	remaining: 9.25s
# 331:	learn: 0.3807770	total: 4.59s	remaining: 9.23s
# 332:	learn: 0.3806138	total: 4.61s	remaining: 9.24s
# 333:	learn: 0.3805904	total: 4.63s	remaining: 9.22s
# 334:	learn: 0.3805853	total: 4.63s	remaining: 9.19s
# 335:	learn: 0.3805840	total: 4.63s	remaining: 9.16s
# 336:	learn: 0.3805373	total: 4.64s	remaining: 9.14s
# 337:	learn: 0.3803711	total: 4.67s	remaining: 9.15s
# 338:	learn: 0.3803295	total: 4.69s	remaining: 9.15s
# 339:	learn: 0.3802471	total: 4.7s	remaining: 9.13s
# 340:	learn: 0.3801347	total: 4.72s	remaining: 9.11s
# 341:	learn: 0.3799741	total: 4.74s	remaining: 9.12s
# 342:	learn: 0.3799741	total: 4.74s	remaining: 9.08s
# 343:	learn: 0.3799268	total: 4.76s	remaining: 9.08s
# 344:	learn: 0.3798298	total: 4.78s	remaining: 9.07s
# 345:	learn: 0.3797613	total: 4.79s	remaining: 9.05s
# 346:	learn: 0.3796301	total: 4.8s	remaining: 9.04s
# 347:	learn: 0.3795740	total: 4.82s	remaining: 9.02s
# 348:	learn: 0.3795286	total: 4.83s	remaining: 9s
# 349:	learn: 0.3794583	total: 4.84s	remaining: 8.98s
# 350:	learn: 0.3794198	total: 4.84s	remaining: 8.95s
# 351:	learn: 0.3793727	total: 4.85s	remaining: 8.93s
# 352:	learn: 0.3793726	total: 4.85s	remaining: 8.89s
# 353:	learn: 0.3791343	total: 4.87s	remaining: 8.89s
# 354:	learn: 0.3791153	total: 4.88s	remaining: 8.87s
# 355:	learn: 0.3789353	total: 4.89s	remaining: 8.86s
# 356:	learn: 0.3788777	total: 4.91s	remaining: 8.84s
# 357:	learn: 0.3788249	total: 4.93s	remaining: 8.84s
# 358:	learn: 0.3787486	total: 4.94s	remaining: 8.82s
# 359:	learn: 0.3787051	total: 4.96s	remaining: 8.81s
# 360:	learn: 0.3786917	total: 4.97s	remaining: 8.79s
# 361:	learn: 0.3786438	total: 4.98s	remaining: 8.77s
# 362:	learn: 0.3786085	total: 4.99s	remaining: 8.76s
# 363:	learn: 0.3785488	total: 5s	remaining: 8.74s
# 364:	learn: 0.3785401	total: 5.04s	remaining: 8.76s
# 365:	learn: 0.3784662	total: 5.05s	remaining: 8.74s
# 366:	learn: 0.3783971	total: 5.06s	remaining: 8.73s
# 367:	learn: 0.3783351	total: 5.08s	remaining: 8.73s
# 368:	learn: 0.3782654	total: 5.09s	remaining: 8.71s
# 369:	learn: 0.3781965	total: 5.11s	remaining: 8.69s
# 370:	learn: 0.3781848	total: 5.13s	remaining: 8.7s
# 371:	learn: 0.3779642	total: 5.14s	remaining: 8.68s
# 372:	learn: 0.3778974	total: 5.15s	remaining: 8.66s
# 373:	learn: 0.3776991	total: 5.16s	remaining: 8.64s
# 374:	learn: 0.3776560	total: 5.17s	remaining: 8.62s
# 375:	learn: 0.3776353	total: 5.2s	remaining: 8.63s
# 376:	learn: 0.3776353	total: 5.21s	remaining: 8.6s
# 377:	learn: 0.3776309	total: 5.22s	remaining: 8.58s
# 378:	learn: 0.3775953	total: 5.23s	remaining: 8.57s
# 379:	learn: 0.3775747	total: 5.24s	remaining: 8.55s
# 380:	learn: 0.3775497	total: 5.25s	remaining: 8.53s
# 381:	learn: 0.3774829	total: 5.26s	remaining: 8.51s
# 382:	learn: 0.3774719	total: 5.27s	remaining: 8.5s
# 383:	learn: 0.3774146	total: 5.29s	remaining: 8.48s
# 384:	learn: 0.3774005	total: 5.32s	remaining: 8.49s
# 385:	learn: 0.3773958	total: 5.33s	remaining: 8.47s
# 386:	learn: 0.3773072	total: 5.33s	remaining: 8.45s
# 387:	learn: 0.3772808	total: 5.34s	remaining: 8.43s
# 388:	learn: 0.3772439	total: 5.35s	remaining: 8.41s
# 389:	learn: 0.3772347	total: 5.36s	remaining: 8.38s
# 390:	learn: 0.3771440	total: 5.37s	remaining: 8.37s
# 391:	learn: 0.3770496	total: 5.38s	remaining: 8.35s
# 392:	learn: 0.3769713	total: 5.39s	remaining: 8.33s
# 393:	learn: 0.3768836	total: 5.41s	remaining: 8.32s
# 394:	learn: 0.3766316	total: 5.42s	remaining: 8.31s
# 395:	learn: 0.3765758	total: 5.46s	remaining: 8.33s
# 396:	learn: 0.3764553	total: 5.47s	remaining: 8.31s
# 397:	learn: 0.3764115	total: 5.48s	remaining: 8.29s
# 398:	learn: 0.3763756	total: 5.51s	remaining: 8.3s
# 399:	learn: 0.3762674	total: 5.53s	remaining: 8.29s
# 400:	learn: 0.3760765	total: 5.54s	remaining: 8.28s
# 401:	learn: 0.3760421	total: 5.55s	remaining: 8.26s
# 402:	learn: 0.3760093	total: 5.56s	remaining: 8.23s
# 403:	learn: 0.3759767	total: 5.57s	remaining: 8.21s
# 404:	learn: 0.3758469	total: 5.59s	remaining: 8.21s
# 405:	learn: 0.3758447	total: 5.6s	remaining: 8.2s
# 406:	learn: 0.3757776	total: 5.63s	remaining: 8.2s
# 407:	learn: 0.3756136	total: 5.65s	remaining: 8.2s
# 408:	learn: 0.3755496	total: 5.67s	remaining: 8.19s
# 409:	learn: 0.3755423	total: 5.68s	remaining: 8.17s
# 410:	learn: 0.3755081	total: 5.69s	remaining: 8.16s
# 411:	learn: 0.3754517	total: 5.72s	remaining: 8.17s
# 412:	learn: 0.3751650	total: 5.75s	remaining: 8.18s
# 413:	learn: 0.3750607	total: 5.77s	remaining: 8.16s
# 414:	learn: 0.3750285	total: 5.78s	remaining: 8.14s
# 415:	learn: 0.3750012	total: 5.79s	remaining: 8.13s
# 416:	learn: 0.3749588	total: 5.81s	remaining: 8.12s
# 417:	learn: 0.3748984	total: 5.82s	remaining: 8.1s
# 418:	learn: 0.3748259	total: 5.83s	remaining: 8.08s
# 419:	learn: 0.3747681	total: 5.86s	remaining: 8.1s
# 420:	learn: 0.3746496	total: 5.87s	remaining: 8.08s
# 421:	learn: 0.3745256	total: 5.88s	remaining: 8.06s
# 422:	learn: 0.3744816	total: 5.89s	remaining: 8.04s
# 423:	learn: 0.3744193	total: 5.9s	remaining: 8.02s
# 424:	learn: 0.3742548	total: 5.91s	remaining: 8s
# 425:	learn: 0.3741763	total: 5.93s	remaining: 7.99s
# 426:	learn: 0.3740460	total: 5.94s	remaining: 7.97s
# 427:	learn: 0.3739266	total: 5.96s	remaining: 7.97s
# 428:	learn: 0.3737390	total: 5.98s	remaining: 7.96s
# 429:	learn: 0.3737203	total: 5.99s	remaining: 7.95s
# 430:	learn: 0.3737031	total: 6s	remaining: 7.93s
# 431:	learn: 0.3735363	total: 6.02s	remaining: 7.92s
# 432:	learn: 0.3735122	total: 6.03s	remaining: 7.9s
# 433:	learn: 0.3735040	total: 6.04s	remaining: 7.87s
# 434:	learn: 0.3733932	total: 6.05s	remaining: 7.85s
# 435:	learn: 0.3732960	total: 6.06s	remaining: 7.84s
# 436:	learn: 0.3731326	total: 6.11s	remaining: 7.87s
# 437:	learn: 0.3731112	total: 6.12s	remaining: 7.85s
# 438:	learn: 0.3729133	total: 6.13s	remaining: 7.83s
# 439:	learn: 0.3728124	total: 6.14s	remaining: 7.81s
# 440:	learn: 0.3726828	total: 6.15s	remaining: 7.79s
# 441:	learn: 0.3726480	total: 6.16s	remaining: 7.78s
# 442:	learn: 0.3725216	total: 6.17s	remaining: 7.76s
# 443:	learn: 0.3724758	total: 6.18s	remaining: 7.74s
# 444:	learn: 0.3723788	total: 6.19s	remaining: 7.72s
# 445:	learn: 0.3723461	total: 6.21s	remaining: 7.71s
# 446:	learn: 0.3722857	total: 6.22s	remaining: 7.69s
# 447:	learn: 0.3722773	total: 6.22s	remaining: 7.67s
# 448:	learn: 0.3721974	total: 6.23s	remaining: 7.64s
# 449:	learn: 0.3721926	total: 6.24s	remaining: 7.63s
# 450:	learn: 0.3721480	total: 6.25s	remaining: 7.61s
# 451:	learn: 0.3721370	total: 6.26s	remaining: 7.59s
# 452:	learn: 0.3719815	total: 6.27s	remaining: 7.58s
# 453:	learn: 0.3718150	total: 6.28s	remaining: 7.56s
# 454:	learn: 0.3717713	total: 6.29s	remaining: 7.54s
# 455:	learn: 0.3717662	total: 6.3s	remaining: 7.52s
# 456:	learn: 0.3715949	total: 6.33s	remaining: 7.52s
# 457:	learn: 0.3715123	total: 6.34s	remaining: 7.51s
# 458:	learn: 0.3714305	total: 6.36s	remaining: 7.49s
# 459:	learn: 0.3712840	total: 6.37s	remaining: 7.47s
# 460:	learn: 0.3711621	total: 6.39s	remaining: 7.47s
# 461:	learn: 0.3710909	total: 6.41s	remaining: 7.46s
# 462:	learn: 0.3710762	total: 6.44s	remaining: 7.47s
# 463:	learn: 0.3710710	total: 6.46s	remaining: 7.46s
# 464:	learn: 0.3708932	total: 6.46s	remaining: 7.44s
# 465:	learn: 0.3707972	total: 6.47s	remaining: 7.42s
# 466:	learn: 0.3706415	total: 6.49s	remaining: 7.4s
# 467:	learn: 0.3705608	total: 6.5s	remaining: 7.38s
# 468:	learn: 0.3704292	total: 6.51s	remaining: 7.37s
# 469:	learn: 0.3703763	total: 6.52s	remaining: 7.35s
# 470:	learn: 0.3703364	total: 6.53s	remaining: 7.33s
# 471:	learn: 0.3701846	total: 6.57s	remaining: 7.34s
# 472:	learn: 0.3701807	total: 6.58s	remaining: 7.33s
# 473:	learn: 0.3700957	total: 6.59s	remaining: 7.31s
# 474:	learn: 0.3699990	total: 6.6s	remaining: 7.29s
# 475:	learn: 0.3699842	total: 6.61s	remaining: 7.28s
# 476:	learn: 0.3698984	total: 6.62s	remaining: 7.26s
# 477:	learn: 0.3698912	total: 6.63s	remaining: 7.24s
# 478:	learn: 0.3698282	total: 6.64s	remaining: 7.22s
# 479:	learn: 0.3698182	total: 6.65s	remaining: 7.2s
# 480:	learn: 0.3696663	total: 6.66s	remaining: 7.19s
# 481:	learn: 0.3695707	total: 6.68s	remaining: 7.18s
# 482:	learn: 0.3695047	total: 6.7s	remaining: 7.17s
# 483:	learn: 0.3693463	total: 6.71s	remaining: 7.15s
# 484:	learn: 0.3691215	total: 6.72s	remaining: 7.14s
# 485:	learn: 0.3689323	total: 6.75s	remaining: 7.14s
# 486:	learn: 0.3689203	total: 6.78s	remaining: 7.14s
# 487:	learn: 0.3688162	total: 6.79s	remaining: 7.13s
# 488:	learn: 0.3687625	total: 6.81s	remaining: 7.11s
# 489:	learn: 0.3686361	total: 6.82s	remaining: 7.1s
# 490:	learn: 0.3685477	total: 6.84s	remaining: 7.09s
# 491:	learn: 0.3684875	total: 6.85s	remaining: 7.08s
# 492:	learn: 0.3683689	total: 6.87s	remaining: 7.06s
# 493:	learn: 0.3683372	total: 6.88s	remaining: 7.04s
# 494:	learn: 0.3682659	total: 6.89s	remaining: 7.03s
# 495:	learn: 0.3681729	total: 6.9s	remaining: 7.01s
# 496:	learn: 0.3679474	total: 6.92s	remaining: 7.01s
# 497:	learn: 0.3679171	total: 6.94s	remaining: 7s
# 498:	learn: 0.3678351	total: 6.95s	remaining: 6.98s
# 499:	learn: 0.3677864	total: 6.96s	remaining: 6.96s
# 500:	learn: 0.3677688	total: 6.97s	remaining: 6.94s
# 501:	learn: 0.3675411	total: 6.98s	remaining: 6.93s
# 502:	learn: 0.3674077	total: 6.99s	remaining: 6.91s
# 503:	learn: 0.3673725	total: 7.01s	remaining: 6.9s
# 504:	learn: 0.3673035	total: 7.02s	remaining: 6.88s
# 505:	learn: 0.3672112	total: 7.03s	remaining: 6.86s
# 506:	learn: 0.3671223	total: 7.04s	remaining: 6.85s
# 507:	learn: 0.3671174	total: 7.06s	remaining: 6.84s
# 508:	learn: 0.3670791	total: 7.07s	remaining: 6.82s
# 509:	learn: 0.3670588	total: 7.08s	remaining: 6.8s
# 510:	learn: 0.3668818	total: 7.12s	remaining: 6.81s
# 511:	learn: 0.3667673	total: 7.14s	remaining: 6.81s
# 512:	learn: 0.3665683	total: 7.15s	remaining: 6.79s
# 513:	learn: 0.3664794	total: 7.16s	remaining: 6.77s
# 514:	learn: 0.3663663	total: 7.17s	remaining: 6.76s
# 515:	learn: 0.3663564	total: 7.21s	remaining: 6.76s
# 516:	learn: 0.3662192	total: 7.23s	remaining: 6.75s
# 517:	learn: 0.3661748	total: 7.25s	remaining: 6.75s
# 518:	learn: 0.3660952	total: 7.29s	remaining: 6.76s
# 519:	learn: 0.3660795	total: 7.3s	remaining: 6.74s
# 520:	learn: 0.3660023	total: 7.31s	remaining: 6.72s
# 521:	learn: 0.3659464	total: 7.33s	remaining: 6.71s
# 522:	learn: 0.3657746	total: 7.34s	remaining: 6.69s
# 523:	learn: 0.3656014	total: 7.35s	remaining: 6.67s
# 524:	learn: 0.3654295	total: 7.36s	remaining: 6.66s
# 525:	learn: 0.3652528	total: 7.37s	remaining: 6.64s
# 526:	learn: 0.3651855	total: 7.38s	remaining: 6.62s
# 527:	learn: 0.3649978	total: 7.39s	remaining: 6.6s
# 528:	learn: 0.3649466	total: 7.4s	remaining: 6.59s
# 529:	learn: 0.3648649	total: 7.45s	remaining: 6.61s
# 530:	learn: 0.3647858	total: 7.47s	remaining: 6.6s
# 531:	learn: 0.3647617	total: 7.49s	remaining: 6.59s
# 532:	learn: 0.3646906	total: 7.5s	remaining: 6.57s
# 533:	learn: 0.3646700	total: 7.51s	remaining: 6.56s
# 534:	learn: 0.3645506	total: 7.56s	remaining: 6.57s
# 535:	learn: 0.3644332	total: 7.58s	remaining: 6.56s
# 536:	learn: 0.3642908	total: 7.59s	remaining: 6.54s
# 537:	learn: 0.3640421	total: 7.6s	remaining: 6.53s
# 538:	learn: 0.3640211	total: 7.62s	remaining: 6.51s
# 539:	learn: 0.3638967	total: 7.63s	remaining: 6.5s
# 540:	learn: 0.3638234	total: 7.64s	remaining: 6.49s
# 541:	learn: 0.3636644	total: 7.66s	remaining: 6.47s
# 542:	learn: 0.3635684	total: 7.7s	remaining: 6.48s
# 543:	learn: 0.3634187	total: 7.72s	remaining: 6.47s
# 544:	learn: 0.3633147	total: 7.74s	remaining: 6.46s
# 545:	learn: 0.3631300	total: 7.75s	remaining: 6.45s
# 546:	learn: 0.3630729	total: 7.76s	remaining: 6.43s
# 547:	learn: 0.3629992	total: 7.77s	remaining: 6.41s
# 548:	learn: 0.3628849	total: 7.78s	remaining: 6.39s
# 549:	learn: 0.3627697	total: 7.8s	remaining: 6.38s
# 550:	learn: 0.3627013	total: 7.82s	remaining: 6.38s
# 551:	learn: 0.3626848	total: 7.84s	remaining: 6.36s
# 552:	learn: 0.3626621	total: 7.85s	remaining: 6.34s
# 553:	learn: 0.3626392	total: 7.86s	remaining: 6.33s
# 554:	learn: 0.3624504	total: 7.87s	remaining: 6.31s
# 555:	learn: 0.3623984	total: 7.9s	remaining: 6.31s
# 556:	learn: 0.3623103	total: 7.92s	remaining: 6.3s
# 557:	learn: 0.3621830	total: 7.93s	remaining: 6.28s
# 558:	learn: 0.3621013	total: 7.95s	remaining: 6.27s
# 559:	learn: 0.3620649	total: 7.97s	remaining: 6.26s
# 560:	learn: 0.3619534	total: 7.98s	remaining: 6.25s
# 561:	learn: 0.3616653	total: 7.99s	remaining: 6.23s
# 562:	learn: 0.3614926	total: 8s	remaining: 6.21s
# 563:	learn: 0.3614128	total: 8.02s	remaining: 6.2s
# 564:	learn: 0.3612750	total: 8.03s	remaining: 6.18s
# 565:	learn: 0.3612140	total: 8.04s	remaining: 6.16s
# 566:	learn: 0.3610943	total: 8.05s	remaining: 6.15s
# 567:	learn: 0.3610549	total: 8.06s	remaining: 6.13s
# 568:	learn: 0.3610356	total: 8.07s	remaining: 6.11s
# 569:	learn: 0.3609772	total: 8.08s	remaining: 6.1s
# 570:	learn: 0.3608231	total: 8.09s	remaining: 6.08s
# 571:	learn: 0.3607220	total: 8.1s	remaining: 6.06s
# 572:	learn: 0.3607026	total: 8.11s	remaining: 6.04s
# 573:	learn: 0.3606143	total: 8.12s	remaining: 6.03s
# 574:	learn: 0.3604699	total: 8.13s	remaining: 6.01s
# 575:	learn: 0.3603972	total: 8.14s	remaining: 5.99s
# 576:	learn: 0.3602800	total: 8.15s	remaining: 5.98s
# 577:	learn: 0.3602174	total: 8.16s	remaining: 5.96s
# 578:	learn: 0.3601631	total: 8.17s	remaining: 5.94s
# 579:	learn: 0.3600149	total: 8.18s	remaining: 5.93s
# 580:	learn: 0.3599328	total: 8.2s	remaining: 5.91s
# 581:	learn: 0.3599177	total: 8.21s	remaining: 5.89s
# 582:	learn: 0.3598793	total: 8.22s	remaining: 5.88s
# 583:	learn: 0.3598096	total: 8.23s	remaining: 5.86s
# 584:	learn: 0.3597583	total: 8.25s	remaining: 5.85s
# 585:	learn: 0.3597129	total: 8.26s	remaining: 5.84s
# 586:	learn: 0.3594978	total: 8.3s	remaining: 5.84s
# 587:	learn: 0.3593517	total: 8.32s	remaining: 5.83s
# 588:	learn: 0.3592288	total: 8.33s	remaining: 5.81s
# 589:	learn: 0.3590979	total: 8.34s	remaining: 5.8s
# 590:	learn: 0.3590790	total: 8.35s	remaining: 5.78s
# 591:	learn: 0.3589737	total: 8.37s	remaining: 5.77s
# 592:	learn: 0.3588766	total: 8.38s	remaining: 5.75s
# 593:	learn: 0.3588629	total: 8.39s	remaining: 5.74s
# 594:	learn: 0.3587317	total: 8.41s	remaining: 5.72s
# 595:	learn: 0.3586344	total: 8.42s	remaining: 5.71s
# 596:	learn: 0.3584951	total: 8.43s	remaining: 5.69s
# 597:	learn: 0.3584815	total: 8.44s	remaining: 5.67s
# 598:	learn: 0.3583832	total: 8.45s	remaining: 5.66s
# 599:	learn: 0.3582764	total: 8.46s	remaining: 5.64s
# 600:	learn: 0.3581229	total: 8.47s	remaining: 5.63s
# 601:	learn: 0.3580042	total: 8.48s	remaining: 5.61s
# 602:	learn: 0.3578531	total: 8.5s	remaining: 5.6s
# 603:	learn: 0.3578034	total: 8.54s	remaining: 5.6s
# 604:	learn: 0.3577769	total: 8.57s	remaining: 5.59s
# 605:	learn: 0.3576970	total: 8.58s	remaining: 5.58s
# 606:	learn: 0.3575917	total: 8.59s	remaining: 5.56s
# 607:	learn: 0.3575001	total: 8.6s	remaining: 5.55s
# 608:	learn: 0.3574777	total: 8.61s	remaining: 5.53s
# 609:	learn: 0.3573527	total: 8.63s	remaining: 5.52s
# 610:	learn: 0.3572018	total: 8.66s	remaining: 5.51s
# 611:	learn: 0.3571099	total: 8.69s	remaining: 5.51s
# 612:	learn: 0.3570349	total: 8.71s	remaining: 5.5s
# 613:	learn: 0.3569496	total: 8.72s	remaining: 5.48s
# 614:	learn: 0.3568355	total: 8.77s	remaining: 5.49s
# 615:	learn: 0.3568227	total: 8.78s	remaining: 5.47s
# 616:	learn: 0.3566339	total: 8.79s	remaining: 5.46s
# 617:	learn: 0.3565500	total: 8.8s	remaining: 5.44s
# 618:	learn: 0.3564810	total: 8.81s	remaining: 5.42s
# 619:	learn: 0.3562924	total: 8.82s	remaining: 5.41s
# 620:	learn: 0.3561860	total: 8.84s	remaining: 5.39s
# 621:	learn: 0.3561674	total: 8.85s	remaining: 5.38s
# 622:	learn: 0.3560501	total: 8.87s	remaining: 5.37s
# 623:	learn: 0.3560151	total: 8.88s	remaining: 5.35s
# 624:	learn: 0.3558887	total: 8.91s	remaining: 5.35s
# 625:	learn: 0.3556723	total: 8.93s	remaining: 5.33s
# 626:	learn: 0.3556173	total: 8.94s	remaining: 5.32s
# 627:	learn: 0.3554576	total: 8.95s	remaining: 5.3s
# 628:	learn: 0.3553276	total: 8.98s	remaining: 5.29s
# 629:	learn: 0.3552988	total: 9.02s	remaining: 5.3s
# 630:	learn: 0.3551940	total: 9.04s	remaining: 5.29s
# 631:	learn: 0.3550062	total: 9.08s	remaining: 5.29s
# 632:	learn: 0.3547664	total: 9.11s	remaining: 5.28s
# 633:	learn: 0.3546981	total: 9.13s	remaining: 5.27s
# 634:	learn: 0.3545529	total: 9.14s	remaining: 5.25s
# 635:	learn: 0.3544694	total: 9.15s	remaining: 5.24s
# 636:	learn: 0.3544035	total: 9.16s	remaining: 5.22s
# 637:	learn: 0.3543906	total: 9.17s	remaining: 5.2s
# 638:	learn: 0.3543376	total: 9.18s	remaining: 5.19s
# 639:	learn: 0.3542282	total: 9.19s	remaining: 5.17s
# 640:	learn: 0.3541926	total: 9.2s	remaining: 5.15s
# 641:	learn: 0.3541652	total: 9.25s	remaining: 5.16s
# 642:	learn: 0.3540418	total: 9.27s	remaining: 5.14s
# 643:	learn: 0.3540379	total: 9.28s	remaining: 5.13s
# 644:	learn: 0.3539545	total: 9.29s	remaining: 5.11s
# 645:	learn: 0.3538545	total: 9.3s	remaining: 5.1s
# 646:	learn: 0.3537523	total: 9.31s	remaining: 5.08s
# 647:	learn: 0.3537453	total: 9.32s	remaining: 5.06s
# 648:	learn: 0.3537430	total: 9.35s	remaining: 5.05s
# 649:	learn: 0.3536928	total: 9.37s	remaining: 5.04s
# 650:	learn: 0.3535834	total: 9.38s	remaining: 5.03s
# 651:	learn: 0.3535304	total: 9.39s	remaining: 5.01s
# 652:	learn: 0.3534916	total: 9.41s	remaining: 5s
# 653:	learn: 0.3534200	total: 9.43s	remaining: 4.99s
# 654:	learn: 0.3533194	total: 9.44s	remaining: 4.97s
# 655:	learn: 0.3532778	total: 9.45s	remaining: 4.95s
# 656:	learn: 0.3531551	total: 9.46s	remaining: 4.94s
# 657:	learn: 0.3531013	total: 9.47s	remaining: 4.92s
# 658:	learn: 0.3530522	total: 9.48s	remaining: 4.91s
# 659:	learn: 0.3529945	total: 9.52s	remaining: 4.91s
# 660:	learn: 0.3528903	total: 9.54s	remaining: 4.89s
# 661:	learn: 0.3528349	total: 9.55s	remaining: 4.88s
# 662:	learn: 0.3527700	total: 9.56s	remaining: 4.86s
# 663:	learn: 0.3526664	total: 9.57s	remaining: 4.84s
# 664:	learn: 0.3526590	total: 9.58s	remaining: 4.83s
# 665:	learn: 0.3525515	total: 9.59s	remaining: 4.81s
# 666:	learn: 0.3524442	total: 9.63s	remaining: 4.81s
# 667:	learn: 0.3524321	total: 9.64s	remaining: 4.79s
# 668:	learn: 0.3523469	total: 9.66s	remaining: 4.78s
# 669:	learn: 0.3523020	total: 9.67s	remaining: 4.76s
# 670:	learn: 0.3522243	total: 9.68s	remaining: 4.75s
# 671:	learn: 0.3521633	total: 9.69s	remaining: 4.73s
# 672:	learn: 0.3521453	total: 9.7s	remaining: 4.71s
# 673:	learn: 0.3520567	total: 9.71s	remaining: 4.7s
# 674:	learn: 0.3519313	total: 9.73s	remaining: 4.69s
# 675:	learn: 0.3518320	total: 9.74s	remaining: 4.67s
# 676:	learn: 0.3517410	total: 9.76s	remaining: 4.65s
# 677:	learn: 0.3515870	total: 9.77s	remaining: 4.64s
# 678:	learn: 0.3514272	total: 9.78s	remaining: 4.62s
# 679:	learn: 0.3512508	total: 9.79s	remaining: 4.61s
# 680:	learn: 0.3512428	total: 9.8s	remaining: 4.59s
# 681:	learn: 0.3511354	total: 9.81s	remaining: 4.57s
# 682:	learn: 0.3509642	total: 9.82s	remaining: 4.56s
# 683:	learn: 0.3507928	total: 9.83s	remaining: 4.54s
# 684:	learn: 0.3506797	total: 9.84s	remaining: 4.52s
# 685:	learn: 0.3506178	total: 9.86s	remaining: 4.51s
# 686:	learn: 0.3504730	total: 9.89s	remaining: 4.51s
# 687:	learn: 0.3504171	total: 9.91s	remaining: 4.5s
# 688:	learn: 0.3503103	total: 9.92s	remaining: 4.48s
# 689:	learn: 0.3502114	total: 9.96s	remaining: 4.48s
# 690:	learn: 0.3501711	total: 9.98s	remaining: 4.46s
# 691:	learn: 0.3501513	total: 9.99s	remaining: 4.45s
# 692:	learn: 0.3500200	total: 10s	remaining: 4.44s
# 693:	learn: 0.3499604	total: 10s	remaining: 4.42s
# 694:	learn: 0.3499046	total: 10.1s	remaining: 4.42s
# 695:	learn: 0.3498746	total: 10.1s	remaining: 4.41s
# 696:	learn: 0.3498059	total: 10.1s	remaining: 4.39s
# 697:	learn: 0.3497946	total: 10.1s	remaining: 4.37s
# 698:	learn: 0.3496496	total: 10.1s	remaining: 4.36s
# 699:	learn: 0.3495096	total: 10.1s	remaining: 4.34s
# 700:	learn: 0.3495017	total: 10.2s	remaining: 4.33s
# 701:	learn: 0.3493871	total: 10.2s	remaining: 4.32s
# 702:	learn: 0.3493414	total: 10.2s	remaining: 4.3s
# 703:	learn: 0.3492312	total: 10.2s	remaining: 4.28s
# 704:	learn: 0.3491075	total: 10.2s	remaining: 4.27s
# 705:	learn: 0.3489800	total: 10.2s	remaining: 4.25s
# 706:	learn: 0.3488626	total: 10.2s	remaining: 4.24s
# 707:	learn: 0.3488188	total: 10.2s	remaining: 4.22s
# 708:	learn: 0.3486664	total: 10.2s	remaining: 4.2s
# 709:	learn: 0.3486607	total: 10.3s	remaining: 4.19s
# 710:	learn: 0.3486244	total: 10.3s	remaining: 4.18s
# 711:	learn: 0.3485275	total: 10.3s	remaining: 4.17s
# 712:	learn: 0.3484903	total: 10.3s	remaining: 4.15s
# 713:	learn: 0.3483442	total: 10.3s	remaining: 4.14s
# 714:	learn: 0.3483062	total: 10.4s	remaining: 4.13s
# 715:	learn: 0.3482547	total: 10.4s	remaining: 4.11s
# 716:	learn: 0.3481861	total: 10.4s	remaining: 4.1s
# 717:	learn: 0.3480349	total: 10.4s	remaining: 4.08s
# 718:	learn: 0.3479975	total: 10.4s	remaining: 4.06s
# 719:	learn: 0.3479333	total: 10.4s	remaining: 4.05s
# 720:	learn: 0.3478437	total: 10.4s	remaining: 4.03s
# 721:	learn: 0.3477995	total: 10.4s	remaining: 4.02s
# 722:	learn: 0.3475444	total: 10.4s	remaining: 4s
# 723:	learn: 0.3475330	total: 10.5s	remaining: 3.98s
# 724:	learn: 0.3474099	total: 10.5s	remaining: 3.97s
# 725:	learn: 0.3473675	total: 10.5s	remaining: 3.96s
# 726:	learn: 0.3473314	total: 10.5s	remaining: 3.94s
# 727:	learn: 0.3472437	total: 10.5s	remaining: 3.92s
# 728:	learn: 0.3471232	total: 10.5s	remaining: 3.91s
# 729:	learn: 0.3469781	total: 10.5s	remaining: 3.9s
# 730:	learn: 0.3469728	total: 10.6s	remaining: 3.88s
# 731:	learn: 0.3469451	total: 10.6s	remaining: 3.87s
# 732:	learn: 0.3468804	total: 10.6s	remaining: 3.85s
# 733:	learn: 0.3468305	total: 10.6s	remaining: 3.84s
# 734:	learn: 0.3467822	total: 10.6s	remaining: 3.83s
# 735:	learn: 0.3467517	total: 10.6s	remaining: 3.81s
# 736:	learn: 0.3465558	total: 10.7s	remaining: 3.8s
# 737:	learn: 0.3465077	total: 10.7s	remaining: 3.79s
# 738:	learn: 0.3464292	total: 10.7s	remaining: 3.77s
# 739:	learn: 0.3464039	total: 10.7s	remaining: 3.76s
# 740:	learn: 0.3463065	total: 10.7s	remaining: 3.75s
# 741:	learn: 0.3462149	total: 10.7s	remaining: 3.73s
# 742:	learn: 0.3460139	total: 10.7s	remaining: 3.71s
# 743:	learn: 0.3459610	total: 10.7s	remaining: 3.7s
# 744:	learn: 0.3459130	total: 10.8s	remaining: 3.68s
# 745:	learn: 0.3458317	total: 10.8s	remaining: 3.67s
# 746:	learn: 0.3457304	total: 10.8s	remaining: 3.66s
# 747:	learn: 0.3455530	total: 10.8s	remaining: 3.65s
# 748:	learn: 0.3455048	total: 10.8s	remaining: 3.63s
# 749:	learn: 0.3453933	total: 10.9s	remaining: 3.62s
# 750:	learn: 0.3453587	total: 10.9s	remaining: 3.6s
# 751:	learn: 0.3452970	total: 10.9s	remaining: 3.59s
# 752:	learn: 0.3452685	total: 10.9s	remaining: 3.57s
# 753:	learn: 0.3452495	total: 10.9s	remaining: 3.56s
# 754:	learn: 0.3451339	total: 10.9s	remaining: 3.54s
# 755:	learn: 0.3450250	total: 10.9s	remaining: 3.52s
# 756:	learn: 0.3450057	total: 10.9s	remaining: 3.51s
# 757:	learn: 0.3448752	total: 10.9s	remaining: 3.49s
# 758:	learn: 0.3448230	total: 11s	remaining: 3.48s
# 759:	learn: 0.3447309	total: 11s	remaining: 3.46s
# 760:	learn: 0.3445690	total: 11s	remaining: 3.45s
# 761:	learn: 0.3444935	total: 11s	remaining: 3.43s
# 762:	learn: 0.3443680	total: 11s	remaining: 3.42s
# 763:	learn: 0.3443302	total: 11s	remaining: 3.4s
# 764:	learn: 0.3442960	total: 11s	remaining: 3.38s
# 765:	learn: 0.3442496	total: 11s	remaining: 3.37s
# 766:	learn: 0.3442095	total: 11s	remaining: 3.35s
# 767:	learn: 0.3441784	total: 11s	remaining: 3.34s
# 768:	learn: 0.3440918	total: 11.1s	remaining: 3.33s
# 769:	learn: 0.3440280	total: 11.1s	remaining: 3.31s
# 770:	learn: 0.3439745	total: 11.1s	remaining: 3.3s
# 771:	learn: 0.3439450	total: 11.1s	remaining: 3.29s
# 772:	learn: 0.3438176	total: 11.1s	remaining: 3.27s
# 773:	learn: 0.3436213	total: 11.1s	remaining: 3.25s
# 774:	learn: 0.3434713	total: 11.2s	remaining: 3.24s
# 775:	learn: 0.3433759	total: 11.2s	remaining: 3.22s
# 776:	learn: 0.3432834	total: 11.2s	remaining: 3.21s
# 777:	learn: 0.3432484	total: 11.2s	remaining: 3.19s
# 778:	learn: 0.3431720	total: 11.2s	remaining: 3.18s
# 779:	learn: 0.3431089	total: 11.2s	remaining: 3.16s
# 780:	learn: 0.3429786	total: 11.2s	remaining: 3.15s
# 781:	learn: 0.3429599	total: 11.2s	remaining: 3.13s
# 782:	learn: 0.3429238	total: 11.2s	remaining: 3.12s
# 783:	learn: 0.3428752	total: 11.3s	remaining: 3.1s
# 784:	learn: 0.3427564	total: 11.3s	remaining: 3.09s
# 785:	learn: 0.3426725	total: 11.3s	remaining: 3.07s
# 786:	learn: 0.3425856	total: 11.3s	remaining: 3.06s
# 787:	learn: 0.3425517	total: 11.3s	remaining: 3.04s
# 788:	learn: 0.3424336	total: 11.3s	remaining: 3.03s
# 789:	learn: 0.3423548	total: 11.3s	remaining: 3.01s
# 790:	learn: 0.3422963	total: 11.3s	remaining: 3s
# 791:	learn: 0.3422053	total: 11.4s	remaining: 2.98s
# 792:	learn: 0.3421449	total: 11.4s	remaining: 2.96s
# 793:	learn: 0.3420457	total: 11.4s	remaining: 2.95s
# 794:	learn: 0.3419627	total: 11.4s	remaining: 2.94s
# 795:	learn: 0.3419004	total: 11.4s	remaining: 2.92s
# 796:	learn: 0.3418682	total: 11.4s	remaining: 2.9s
# 797:	learn: 0.3417746	total: 11.4s	remaining: 2.89s
# 798:	learn: 0.3417585	total: 11.4s	remaining: 2.87s
# 799:	learn: 0.3416513	total: 11.5s	remaining: 2.86s
# 800:	learn: 0.3415017	total: 11.5s	remaining: 2.85s
# 801:	learn: 0.3414186	total: 11.5s	remaining: 2.83s
# 802:	learn: 0.3413474	total: 11.5s	remaining: 2.83s
# 803:	learn: 0.3411328	total: 11.6s	remaining: 2.82s
# 804:	learn: 0.3410705	total: 11.6s	remaining: 2.8s
# 805:	learn: 0.3409527	total: 11.6s	remaining: 2.79s
# 806:	learn: 0.3408367	total: 11.6s	remaining: 2.77s
# 807:	learn: 0.3407328	total: 11.6s	remaining: 2.75s
# 808:	learn: 0.3407110	total: 11.6s	remaining: 2.74s
# 809:	learn: 0.3407006	total: 11.6s	remaining: 2.73s
# 810:	learn: 0.3406961	total: 11.6s	remaining: 2.71s
# 811:	learn: 0.3406077	total: 11.7s	remaining: 2.7s
# 812:	learn: 0.3405730	total: 11.7s	remaining: 2.69s
# 813:	learn: 0.3404949	total: 11.7s	remaining: 2.67s
# 814:	learn: 0.3404003	total: 11.7s	remaining: 2.65s
# 815:	learn: 0.3403706	total: 11.7s	remaining: 2.64s
# 816:	learn: 0.3403453	total: 11.8s	remaining: 2.63s
# 817:	learn: 0.3403143	total: 11.8s	remaining: 2.62s
# 818:	learn: 0.3402898	total: 11.8s	remaining: 2.6s
# 819:	learn: 0.3402740	total: 11.8s	remaining: 2.59s
# 820:	learn: 0.3401675	total: 11.8s	remaining: 2.57s
# 821:	learn: 0.3399871	total: 11.8s	remaining: 2.56s
# 822:	learn: 0.3399722	total: 11.8s	remaining: 2.54s
# 823:	learn: 0.3399383	total: 11.8s	remaining: 2.53s
# 824:	learn: 0.3398806	total: 11.8s	remaining: 2.51s
# 825:	learn: 0.3397618	total: 11.9s	remaining: 2.5s
# 826:	learn: 0.3396646	total: 11.9s	remaining: 2.48s
# 827:	learn: 0.3396294	total: 11.9s	remaining: 2.47s
# 828:	learn: 0.3396253	total: 11.9s	remaining: 2.45s
# 829:	learn: 0.3396005	total: 11.9s	remaining: 2.44s
# 830:	learn: 0.3395799	total: 11.9s	remaining: 2.42s
# 831:	learn: 0.3394507	total: 11.9s	remaining: 2.41s
# 832:	learn: 0.3392162	total: 12s	remaining: 2.4s
# 833:	learn: 0.3390878	total: 12s	remaining: 2.38s
# 834:	learn: 0.3389666	total: 12s	remaining: 2.37s
# 835:	learn: 0.3389455	total: 12s	remaining: 2.35s
# 836:	learn: 0.3389114	total: 12s	remaining: 2.34s
# 837:	learn: 0.3388162	total: 12s	remaining: 2.32s
# 838:	learn: 0.3386915	total: 12s	remaining: 2.31s
# 839:	learn: 0.3385951	total: 12s	remaining: 2.29s
# 840:	learn: 0.3384663	total: 12.1s	remaining: 2.28s
# 841:	learn: 0.3383804	total: 12.1s	remaining: 2.26s
# 842:	learn: 0.3382786	total: 12.1s	remaining: 2.25s
# 843:	learn: 0.3382638	total: 12.1s	remaining: 2.23s
# 844:	learn: 0.3382599	total: 12.1s	remaining: 2.22s
# 845:	learn: 0.3382361	total: 12.1s	remaining: 2.21s
# 846:	learn: 0.3382036	total: 12.1s	remaining: 2.19s
# 847:	learn: 0.3381614	total: 12.2s	remaining: 2.18s
# 848:	learn: 0.3381411	total: 12.2s	remaining: 2.17s
# 849:	learn: 0.3380840	total: 12.2s	remaining: 2.15s
# 850:	learn: 0.3379780	total: 12.2s	remaining: 2.14s
# 851:	learn: 0.3377372	total: 12.2s	remaining: 2.12s
# 852:	learn: 0.3377181	total: 12.2s	remaining: 2.11s
# 853:	learn: 0.3376050	total: 12.2s	remaining: 2.09s
# 854:	learn: 0.3372669	total: 12.3s	remaining: 2.08s
# 855:	learn: 0.3371707	total: 12.3s	remaining: 2.06s
# 856:	learn: 0.3370757	total: 12.3s	remaining: 2.05s
# 857:	learn: 0.3369432	total: 12.3s	remaining: 2.04s
# 858:	learn: 0.3368149	total: 12.3s	remaining: 2.02s
# 859:	learn: 0.3367254	total: 12.4s	remaining: 2.01s
# 860:	learn: 0.3366637	total: 12.4s	remaining: 2s
# 861:	learn: 0.3365718	total: 12.4s	remaining: 1.99s
# 862:	learn: 0.3365326	total: 12.4s	remaining: 1.97s
# 863:	learn: 0.3363699	total: 12.4s	remaining: 1.96s
# 864:	learn: 0.3363503	total: 12.5s	remaining: 1.95s
# 865:	learn: 0.3363222	total: 12.5s	remaining: 1.93s
# 866:	learn: 0.3362146	total: 12.5s	remaining: 1.92s
# 867:	learn: 0.3360848	total: 12.5s	remaining: 1.9s
# 868:	learn: 0.3359397	total: 12.5s	remaining: 1.89s
# 869:	learn: 0.3359258	total: 12.5s	remaining: 1.87s
# 870:	learn: 0.3358155	total: 12.5s	remaining: 1.86s
# 871:	learn: 0.3356678	total: 12.6s	remaining: 1.84s
# 872:	learn: 0.3355616	total: 12.6s	remaining: 1.83s
# 873:	learn: 0.3354251	total: 12.6s	remaining: 1.82s
# 874:	learn: 0.3353943	total: 12.6s	remaining: 1.8s
# 875:	learn: 0.3352901	total: 12.6s	remaining: 1.79s
# 876:	learn: 0.3352291	total: 12.6s	remaining: 1.77s
# 877:	learn: 0.3350976	total: 12.7s	remaining: 1.76s
# 878:	learn: 0.3350007	total: 12.7s	remaining: 1.74s
# 879:	learn: 0.3349468	total: 12.7s	remaining: 1.73s
# 880:	learn: 0.3348483	total: 12.7s	remaining: 1.72s
# 881:	learn: 0.3348232	total: 12.8s	remaining: 1.71s
# 882:	learn: 0.3347853	total: 12.8s	remaining: 1.69s
# 883:	learn: 0.3347769	total: 12.8s	remaining: 1.68s
# 884:	learn: 0.3347018	total: 12.8s	remaining: 1.67s
# 885:	learn: 0.3345515	total: 12.8s	remaining: 1.65s
# 886:	learn: 0.3344618	total: 12.8s	remaining: 1.64s
# 887:	learn: 0.3344292	total: 12.9s	remaining: 1.63s
# 888:	learn: 0.3343567	total: 12.9s	remaining: 1.61s
# 889:	learn: 0.3343476	total: 12.9s	remaining: 1.6s
# 890:	learn: 0.3343378	total: 12.9s	remaining: 1.58s
# 891:	learn: 0.3342354	total: 13s	remaining: 1.57s
# 892:	learn: 0.3341047	total: 13s	remaining: 1.55s
# 893:	learn: 0.3340761	total: 13s	remaining: 1.54s
# 894:	learn: 0.3339718	total: 13s	remaining: 1.53s
# 895:	learn: 0.3339078	total: 13s	remaining: 1.51s
# 896:	learn: 0.3339009	total: 13.1s	remaining: 1.5s
# 897:	learn: 0.3338915	total: 13.1s	remaining: 1.48s
# 898:	learn: 0.3337981	total: 13.1s	remaining: 1.47s
# 899:	learn: 0.3336697	total: 13.1s	remaining: 1.46s
# 900:	learn: 0.3336426	total: 13.1s	remaining: 1.44s
# 901:	learn: 0.3335495	total: 13.1s	remaining: 1.43s
# 902:	learn: 0.3334620	total: 13.1s	remaining: 1.41s
# 903:	learn: 0.3334078	total: 13.2s	remaining: 1.4s
# 904:	learn: 0.3333868	total: 13.2s	remaining: 1.38s
# 905:	learn: 0.3333774	total: 13.2s	remaining: 1.37s
# 906:	learn: 0.3333228	total: 13.2s	remaining: 1.35s
# 907:	learn: 0.3331708	total: 13.2s	remaining: 1.34s
# 908:	learn: 0.3330811	total: 13.2s	remaining: 1.32s
# 909:	learn: 0.3330237	total: 13.2s	remaining: 1.31s
# 910:	learn: 0.3329557	total: 13.3s	remaining: 1.29s
# 911:	learn: 0.3329051	total: 13.3s	remaining: 1.28s
# 912:	learn: 0.3328615	total: 13.3s	remaining: 1.27s
# 913:	learn: 0.3328032	total: 13.3s	remaining: 1.25s
# 914:	learn: 0.3327583	total: 13.4s	remaining: 1.24s
# 915:	learn: 0.3326261	total: 13.4s	remaining: 1.23s
# 916:	learn: 0.3325289	total: 13.4s	remaining: 1.21s
# 917:	learn: 0.3324418	total: 13.4s	remaining: 1.2s
# 918:	learn: 0.3324210	total: 13.4s	remaining: 1.18s
# 919:	learn: 0.3323897	total: 13.4s	remaining: 1.17s
# 920:	learn: 0.3322602	total: 13.5s	remaining: 1.16s
# 921:	learn: 0.3321223	total: 13.5s	remaining: 1.14s
# 922:	learn: 0.3320827	total: 13.5s	remaining: 1.13s
# 923:	learn: 0.3320584	total: 13.5s	remaining: 1.11s
# 924:	learn: 0.3320216	total: 13.5s	remaining: 1.1s
# 925:	learn: 0.3319361	total: 13.5s	remaining: 1.08s
# 926:	learn: 0.3319296	total: 13.6s	remaining: 1.07s
# 927:	learn: 0.3317968	total: 13.6s	remaining: 1.05s
# 928:	learn: 0.3317781	total: 13.6s	remaining: 1.04s
# 929:	learn: 0.3316703	total: 13.6s	remaining: 1.02s
# 930:	learn: 0.3316438	total: 13.6s	remaining: 1.01s
# 931:	learn: 0.3315874	total: 13.6s	remaining: 993ms
# 932:	learn: 0.3315499	total: 13.6s	remaining: 978ms
# 933:	learn: 0.3314869	total: 13.6s	remaining: 963ms
# 934:	learn: 0.3314527	total: 13.6s	remaining: 948ms
# 935:	learn: 0.3313980	total: 13.7s	remaining: 933ms
# 936:	learn: 0.3313537	total: 13.7s	remaining: 919ms
# 937:	learn: 0.3312375	total: 13.7s	remaining: 904ms
# 938:	learn: 0.3311811	total: 13.7s	remaining: 890ms
# 939:	learn: 0.3311119	total: 13.7s	remaining: 875ms
# 940:	learn: 0.3309001	total: 13.7s	remaining: 861ms
# 941:	learn: 0.3308438	total: 13.8s	remaining: 847ms
# 942:	learn: 0.3307894	total: 13.8s	remaining: 833ms
# 943:	learn: 0.3307712	total: 13.8s	remaining: 818ms
# 944:	learn: 0.3307632	total: 13.8s	remaining: 803ms
# 945:	learn: 0.3307569	total: 13.8s	remaining: 788ms
# 946:	learn: 0.3305372	total: 13.8s	remaining: 774ms
# 947:	learn: 0.3304411	total: 13.8s	remaining: 759ms
# 948:	learn: 0.3303325	total: 13.9s	remaining: 745ms
# 949:	learn: 0.3302887	total: 13.9s	remaining: 731ms
# 950:	learn: 0.3301534	total: 13.9s	remaining: 716ms
# 951:	learn: 0.3301368	total: 13.9s	remaining: 701ms
# 952:	learn: 0.3299259	total: 13.9s	remaining: 686ms
# 953:	learn: 0.3297815	total: 13.9s	remaining: 672ms
# 954:	learn: 0.3297707	total: 13.9s	remaining: 657ms
# 955:	learn: 0.3296657	total: 14s	remaining: 642ms
# 956:	learn: 0.3296229	total: 14s	remaining: 627ms
# 957:	learn: 0.3295805	total: 14s	remaining: 613ms
# 958:	learn: 0.3295180	total: 14s	remaining: 599ms
# 959:	learn: 0.3294817	total: 14s	remaining: 584ms
# 960:	learn: 0.3294556	total: 14s	remaining: 569ms
# 961:	learn: 0.3293453	total: 14s	remaining: 554ms
# 962:	learn: 0.3293278	total: 14s	remaining: 540ms
# 963:	learn: 0.3292356	total: 14.1s	remaining: 525ms
# 964:	learn: 0.3291062	total: 14.1s	remaining: 510ms
# 965:	learn: 0.3290223	total: 14.1s	remaining: 496ms
# 966:	learn: 0.3289792	total: 14.1s	remaining: 482ms
# 967:	learn: 0.3289256	total: 14.1s	remaining: 467ms
# 968:	learn: 0.3287988	total: 14.1s	remaining: 453ms
# 969:	learn: 0.3287495	total: 14.2s	remaining: 438ms
# 970:	learn: 0.3286346	total: 14.2s	remaining: 423ms
# 971:	learn: 0.3285721	total: 14.2s	remaining: 409ms
# 972:	learn: 0.3284514	total: 14.2s	remaining: 395ms
# 973:	learn: 0.3283893	total: 14.2s	remaining: 380ms
# 974:	learn: 0.3282730	total: 14.3s	remaining: 365ms
# 975:	learn: 0.3282521	total: 14.3s	remaining: 351ms
# 976:	learn: 0.3281106	total: 14.3s	remaining: 336ms
# 977:	learn: 0.3280137	total: 14.3s	remaining: 322ms
# 978:	learn: 0.3279046	total: 14.3s	remaining: 307ms
# 979:	learn: 0.3276979	total: 14.3s	remaining: 293ms
# 980:	learn: 0.3276715	total: 14.4s	remaining: 278ms
# 981:	learn: 0.3276166	total: 14.4s	remaining: 264ms
# 982:	learn: 0.3275818	total: 14.4s	remaining: 249ms
# 983:	learn: 0.3274920	total: 14.4s	remaining: 234ms
# 984:	learn: 0.3274797	total: 14.4s	remaining: 220ms
# 985:	learn: 0.3273304	total: 14.4s	remaining: 205ms
# 986:	learn: 0.3273245	total: 14.4s	remaining: 190ms
# 987:	learn: 0.3272353	total: 14.5s	remaining: 176ms
# 988:	learn: 0.3270885	total: 14.5s	remaining: 161ms
# 989:	learn: 0.3270181	total: 14.5s	remaining: 146ms
# 990:	learn: 0.3269888	total: 14.5s	remaining: 132ms
# 991:	learn: 0.3269497	total: 14.5s	remaining: 117ms
# 992:	learn: 0.3268519	total: 14.5s	remaining: 102ms
# 993:	learn: 0.3268318	total: 14.5s	remaining: 87.7ms
# 994:	learn: 0.3267553	total: 14.6s	remaining: 73.2ms
# 995:	learn: 0.3266209	total: 14.6s	remaining: 58.6ms
# 996:	learn: 0.3265618	total: 14.6s	remaining: 44ms
# 997:	learn: 0.3264426	total: 14.6s	remaining: 29.3ms
# 998:	learn: 0.3264240	total: 14.6s	remaining: 14.6ms
# 999:	learn: 0.3263126	total: 14.6s	remaining: 0us

# %%
y_train_predicted = boosting_model.predict_proba(X_train_cb)[:, 1]
y_valid_predicted = boosting_model.predict_proba(X_valid_cb)[:, 1]

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
valid_auc = roc_auc_score(y_valid, y_valid_predicted)

plt.figure(figsize=(20,10))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_valid, y_valid_predicted)[:2], label='valid AUC={:.4f}'.format(valid_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %% [markdown]
# - Из деревьев получилось, что катбуст лучше всех справился.
# - Параметры модели по умолчанию
# - Точность на валидационной выборке 0.8532

# %% [markdown]
# # Предсказания

# %% [markdown]
# Заново загрузим и обработает данные.

# %%
data = pd.read_csv('./train.csv')
TotalSpent_median = 0

# %%
def prepare_data_train(df):
    df.loc[df['TotalSpent'] == ' ', 'TotalSpent'] = np.nan
    df['TotalSpent'] = df['TotalSpent'].astype(float) # Поменяем тип
    TotalSpent_median = df['TotalSpent'].median()
    df.loc[df['TotalSpent'].isnull(), 'TotalSpent'] = TotalSpent_median
    df['IsSeniorCitizen'] = df['IsSeniorCitizen'].astype(object) # Сделаем категориальную переменную, категориальной.
    X = pd.get_dummies(df[feature_cols], drop_first=True)
    return X

# %%
def prepare_data_test(df):
    df.loc[df['TotalSpent'] == ' ', 'TotalSpent'] = np.nan
    df['TotalSpent'] = df['TotalSpent'].astype(float) # Поменяем тип
    df.loc[df['TotalSpent'].isnull(), 'TotalSpent'] = TotalSpent_median
    df['IsSeniorCitizen'] = df['IsSeniorCitizen'].astype(object) # Сделаем категориальную переменную, категориальной.
    X = pd.get_dummies(df[feature_cols], drop_first=True)
    return X

# %%
X_train = prepare_data_train(data)
y_train = data['Churn']

# %% [markdown]
# Обучим лидера.

# %%
best_model = RandomForestClassifier(max_depth = 5, max_features = 'sqrt', n_estimators = 200)
best_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features='sqrt', n_estimators=200)

# %%
X_test = pd.read_csv('./test.csv')

# %%
X_test = prepare_data_test(X_test)

# %%
submission = pd.read_csv('./submission.csv')

# %%
submission['Churn'] = best_model.predict_proba(X_test)[:, 1]

# %%
submission.to_csv('./my_submission.csv', index = False)

# %% [markdown]
# # Kaggle (5 баллов)
#
# Как выставить баллы:
#
# 1) 1 >= roc auc > 0.84 это 5 баллов
#
# 2) 0.84 >= roc auc > 0.7 это 3 балла
#
# 3) 0.7 >= roc auc > 0.6 это 1 балл
#
# 4) 0.6 >= roc auc это 0 баллов
#
#
# Для выполнения задания необходимо выполнить следующие шаги.
# * Зарегистрироваться на платформе [kaggle.com](kaggle.com). Процесс выставления оценок будет проходить при подведении итогового рейтинга. Пожалуйста, укажите во вкладке Team -> Team name свои имя и фамилию в формате Имя_Фамилия (важно, чтобы имя и фамилия совпадали с данными на Stepik).
# * Обучить модель, получить файл с ответами в формате .csv и сдать его в конкурс. Пробуйте и экспериментируйте. Обратите внимание, что вы можете выполнять до 20 попыток сдачи на kaggle в день.
# * После окончания соревнования отправить в итоговый ноутбук с решением на степик.
# * После дедлайна проверьте посылки других участников по критериям. Для этого надо зайти на степик, скачать их ноутбук и проверить скор в соревновании.
